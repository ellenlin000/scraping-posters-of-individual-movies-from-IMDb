# %% [markdown]
# <h1>RECORDS OF UPDATEING...</h1>
# <ul>
#     <li>using file: <b style="color: red">auto_labeled_sort_with_box_office_1997-2017.csv</b>
#     </li>
# </ul>
# <p>
# num_to_Rnum_dict = {'Rnum_year_box_office_label': { 9:'R9', 8:'R8', 7:'R7', 6:'R6', 5:'R5', 4:'R4', 3:'R3', 2:'R2', 1:'R1', 0:'R0' }}      # label = column name
# df_10038.replace(num_to_Rnum_dict, inplace = True)</p>

# %%
import os
import requests
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from math import log
from collections import Counter

# %matplotlib inline

# %%
CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, year, Rnum, group_num):
    """download all images in list 'urls' to 'path' """
    #path='train/'
    re = requests.get(urls[0])#get the first one pic of url
    def get_first_pic(r, num_i, group_num): 
        filetype = r.headers['content-type'].split('/')[-1]
        threshold = int(len(df_sort_y_Rnum.get_group((year, Rnum)))*0.8)
        print('threshold: ', threshold)
        if group_num < threshold:
                print('num_i: ', num_i)
                filename = '{0}.{1}.{2}.{3}'.format(Rnum, group_num, year, filetype)
                path = 'train/'
                filepath = os.path.join(path, filename)
                print('filepath: ',filepath)
                with open(filepath,'wb') as w:
                    w.write(r.content)
                    print('OK')
        else:
            print('num_i: ', num_i)
            filename = '{0}.{1}.{2}.{3}'.format(Rnum, group_num, year, filetype)
            path = 'test/'
            filepath = os.path.join(path, filename)
            print('filepath: ',filepath)
            with open(filepath,'wb') as w:
                w.write(r.content)
                print('OK')
        print('now I have downloaded the first movie poster of number', i)
    get_first_pic(re, i, list_of_group[i])
    
def get_poster_urls(imdbid):
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, list_of_year[i], list_of_Rnum[i], list_of_group[i])
    
def get_id_from_file_n_create_dataframe(address):
    df = pd.read_csv(address)
    list_of_id = df.imdb_id
    list_of_year = df.year
    list_of_Rnum = df.Rnum_year_box_office_label
    list_of_group = df.groups_num
    return df, list_of_id, list_of_year, list_of_Rnum, list_of_group

if __name__=="__main__":
    print('---STAR---')
    print()
    print('...Ready to get IMDb id from file')
    df, list_of_movie_id, list_of_year, list_of_Rnum, list_of_group = get_id_from_file_n_create_dataframe('v3_auto_labeled_sort_with_box_office_1997-2017.csv')
    print('Sucess...')
    print()
    print('...Ready to group the new dataframa by "year" and "Rnum_year_box_office_label"')
    df_sort_y_Rnum = df_10038.groupby(['year', 'Rnum_year_box_office_label'])
    print('Sucess...')
    print()
    print('...Ready to download the movie poster in individual movie')
    for i in range(991, 1020):
        print('now is the number ' , i+1 , ' : ', list_of_movie_id[i])
        tmdb_posters(list_of_movie_id[i])
        print('***now the execution have done this time in the local host***')
        print()
    print('---FINISHED---')
# Out:
# ---STAR---
#
# ...Ready to get IMDb id from file
# Sucess...
#
# ...Ready to group the new dataframa by "year" and "Rnum_year_box_office_label"
# Sucess...
#
# ...Ready to download the movie poster in individual movie
# now is the number  992  :  tt0119675
# threshold:  15
# num_i:  991
# filepath:  test/R9.16.1997.jpeg
# OK
# now I have downloaded the first movie poster of number 991
# ***now the execution have done this time in the local host***
#
# now is the number  993  :  tt0119215
# threshold:  15
# num_i:  992
# filepath:  test/R9.17.1997.jpeg
# OK
# now I have downloaded the first movie poster of number 992
# ***now the execution have done this time in the local host***
#
# now is the number  994  :  tt0119311
# threshold:  15
# num_i:  993
# filepath:  test/R9.18.1997.jpeg
# OK
# now I have downloaded the first movie poster of number 993
# ***now the execution have done this time in the local host***
#
# now is the number  995  :  tt1285009
# threshold:  93
# num_i:  994
# filepath:  train/R8.0.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 994
# ***now the execution have done this time in the local host***
#
# now is the number  996  :  tt5699154
# threshold:  93
# num_i:  995
# filepath:  train/R8.1.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 995
# ***now the execution have done this time in the local host***
#
# now is the number  997  :  tt7645502
# threshold:  93
# num_i:  996
# filepath:  train/R8.2.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 996
# ***now the execution have done this time in the local host***
#
# now is the number  998  :  tt6421110
# threshold:  93
# num_i:  997
# filepath:  train/R8.3.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 997
# ***now the execution have done this time in the local host***
#
# now is the number  999  :  tt5390504
# threshold:  93
# num_i:  998
# filepath:  train/R8.4.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 998
# ***now the execution have done this time in the local host***
#
# now is the number  1000  :  tt6021478
# threshold:  93
# num_i:  999
# filepath:  train/R8.5.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 999
# ***now the execution have done this time in the local host***
#
# now is the number  1001  :  tt3829920
# threshold:  93
# num_i:  1000
# filepath:  train/R8.6.2017.jpeg
# OK
# now I have downloaded the first movie poster of number 1000
# ***now the execution have done this time in the local host***
#
# now is the number  1002  :  tt5882970
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/linyujing/anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-4c53ae9e4ec5> in <module>()
#      82     for i in range(991, 1020):
#      83         print('now is the number ' , i+1 , ' : ', list_of_movie_id[i])
# ---> 84         tmdb_posters(list_of_movie_id[i])
#      85         print('***now the execution have done this time in the local host***')
#      86         print()
#
# <ipython-input-30-4c53ae9e4ec5> in tmdb_posters(imdbid, count, outpath)
#      55
#      56 def tmdb_posters(imdbid, count=None, outpath='.'):
# ---> 57     urls = get_poster_urls(imdbid)
#      58     if count is not None:
#      59         urls = urls[:count]
#
# <ipython-input-30-4c53ae9e4ec5> in get_poster_urls(imdbid)
#      45     max_size = max(sizes, key=size_str_to_int)
#      46
# ---> 47     posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
#      48     poster_urls = []
#      49     for poster in posters:
#
# <ipython-input-30-4c53ae9e4ec5> in _get_json(url)
#       3
#       4 def _get_json(url):
# ----> 5     r = requests.get(url)
#       6     return r.json()
#       7
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/linyujing/anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/linyujing/anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/linyujing/anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/linyujing/anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/linyujing/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df_10038 = pd.read_csv('v2_auto_labeled_sort_with_box_office_1997-2017.csv')

# %%
df_10038.head()
# Out:
#    Unnamed: 0  previous_index_num  movie_title_txt_num    imdb_id  \
# 0           0                   0                    1  tt1825683
# 1           1                   8                    9  tt3469046
# 2           2                6451                 6790  tt7131870
# 3           3                  13                   14  tt3501632
# 4           4                   4                    5  tt2380307
#
#    number_of _posters  total_box_office  with_adjusted_box_office  \
# 0                 108        1273623549                1273623549
# 1                  80        1034542646                1034542646
# 2                  14         861434171                 861434171
# 3                 105         850653412                 850653412
# 4                  71         780299991                 780299991
#
#    total_label  year      movie_title  year_box_office_label  \
# 0            9  2017    Black Panther                      9
# 1            9  2017  Despicable Me 3                      9
# 2            9  2017     Zhan Lang 2                       9
# 3            9  2017    Thor Ragnarok                      9
# 4            9  2017            Coco                       9
#
#   Rnum_year_box_office_label  groups_num
# 0                         R9           0
# 1                         R9           1
# 2                         R9           2
# 3                         R9           3
# 4                         R9           4

# %%
df_10038.to_csv('v3_auto_labeled_sort_with_box_office_1997-2017.csv')

# %%
df_10038['groups_num'] = 0

# %%
df_sort_y_Rnum = df_10038.groupby(['year', 'Rnum_year_box_office_label'])


for sp_keys in df_sort_y_Rnum.groups.keys():
    print('sp_key: ',sp_keys)
    spcified_year_df = df_sort_y_Rnum.get_group(sp_keys)
    spcified_year_df['iloc_i'] = range(0, len(spcified_year_df))
    index_num_list = spcified_year_df['iloc_i'].index
    #print(index_num_list[0])
    for index_i in range(0,len(index_num_list)):
        #print(index_i)
        value = index_num_list[index_i]
        #print('value: ', value)
        df_10038['groups_num'][value] = index_i
# Out:
# sp_key:  (1997, 'R0')
# /Users/linyujing/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/linyujing/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# sp_key:  (1997, 'R1')
# sp_key:  (1997, 'R2')
# sp_key:  (1997, 'R3')
# sp_key:  (1997, 'R4')
# sp_key:  (1997, 'R5')
# sp_key:  (1997, 'R6')
# sp_key:  (1997, 'R7')
# sp_key:  (1997, 'R8')
# sp_key:  (1997, 'R9')
# sp_key:  (1998, 'R0')
# sp_key:  (1998, 'R1')
# sp_key:  (1998, 'R2')
# sp_key:  (1998, 'R3')
# sp_key:  (1998, 'R4')
# sp_key:  (1998, 'R5')
# sp_key:  (1998, 'R6')
# sp_key:  (1998, 'R7')
# sp_key:  (1998, 'R8')
# sp_key:  (1998, 'R9')
# sp_key:  (1999, 'R0')
# sp_key:  (1999, 'R1')
# sp_key:  (1999, 'R2')
# sp_key:  (1999, 'R3')
# sp_key:  (1999, 'R4')
# sp_key:  (1999, 'R5')
# sp_key:  (1999, 'R6')
# sp_key:  (1999, 'R7')
# sp_key:  (1999, 'R8')
# sp_key:  (1999, 'R9')
# sp_key:  (2000, 'R0')
# sp_key:  (2000, 'R1')
# sp_key:  (2000, 'R2')
# sp_key:  (2000, 'R3')
# sp_key:  (2000, 'R4')
# sp_key:  (2000, 'R5')
# sp_key:  (2000, 'R6')
# sp_key:  (2000, 'R7')
# sp_key:  (2000, 'R8')
# sp_key:  (2000, 'R9')
# sp_key:  (2001, 'R0')
# sp_key:  (2001, 'R1')
# sp_key:  (2001, 'R2')
# sp_key:  (2001, 'R3')
# sp_key:  (2001, 'R4')
# sp_key:  (2001, 'R5')
# sp_key:  (2001, 'R6')
# sp_key:  (2001, 'R7')
# sp_key:  (2001, 'R8')
# sp_key:  (2001, 'R9')
# sp_key:  (2002, 'R0')
# sp_key:  (2002, 'R1')
# sp_key:  (2002, 'R2')
# sp_key:  (2002, 'R3')
# sp_key:  (2002, 'R4')
# sp_key:  (2002, 'R5')
# sp_key:  (2002, 'R6')
# sp_key:  (2002, 'R7')
# sp_key:  (2002, 'R8')
# sp_key:  (2002, 'R9')
# sp_key:  (2003, 'R0')
# sp_key:  (2003, 'R1')
# sp_key:  (2003, 'R2')
# sp_key:  (2003, 'R3')
# sp_key:  (2003, 'R4')
# sp_key:  (2003, 'R5')
# sp_key:  (2003, 'R6')
# sp_key:  (2003, 'R7')
# sp_key:  (2003, 'R8')
# sp_key:  (2003, 'R9')
# sp_key:  (2004, 'R0')
# sp_key:  (2004, 'R1')
# sp_key:  (2004, 'R2')
# sp_key:  (2004, 'R3')
# sp_key:  (2004, 'R4')
# sp_key:  (2004, 'R5')
# sp_key:  (2004, 'R6')
# sp_key:  (2004, 'R7')
# sp_key:  (2004, 'R8')
# sp_key:  (2004, 'R9')
# sp_key:  (2005, 'R0')
# sp_key:  (2005, 'R1')
# sp_key:  (2005, 'R2')
# sp_key:  (2005, 'R3')
# sp_key:  (2005, 'R4')
# sp_key:  (2005, 'R5')
# sp_key:  (2005, 'R6')
# sp_key:  (2005, 'R7')
# sp_key:  (2005, 'R8')
# sp_key:  (2005, 'R9')
# sp_key:  (2006, 'R0')
# sp_key:  (2006, 'R1')
# sp_key:  (2006, 'R2')
# sp_key:  (2006, 'R3')
# sp_key:  (2006, 'R4')
# sp_key:  (2006, 'R5')
# sp_key:  (2006, 'R6')
# sp_key:  (2006, 'R7')
# sp_key:  (2006, 'R8')
# sp_key:  (2006, 'R9')
# sp_key:  (2007, 'R0')
# sp_key:  (2007, 'R1')
# sp_key:  (2007, 'R2')
# sp_key:  (2007, 'R3')
# sp_key:  (2007, 'R4')
# sp_key:  (2007, 'R5')
# sp_key:  (2007, 'R6')
# sp_key:  (2007, 'R7')
# sp_key:  (2007, 'R8')
# sp_key:  (2007, 'R9')
# sp_key:  (2008, 'R0')
# sp_key:  (2008, 'R1')
# sp_key:  (2008, 'R2')
# sp_key:  (2008, 'R3')
# sp_key:  (2008, 'R4')
# sp_key:  (2008, 'R5')
# sp_key:  (2008, 'R6')
# sp_key:  (2008, 'R7')
# sp_key:  (2008, 'R8')
# sp_key:  (2008, 'R9')
# sp_key:  (2009, 'R0')
# sp_key:  (2009, 'R1')
# sp_key:  (2009, 'R2')
# sp_key:  (2009, 'R3')
# sp_key:  (2009, 'R4')
# sp_key:  (2009, 'R5')
# sp_key:  (2009, 'R6')
# sp_key:  (2009, 'R7')
# sp_key:  (2009, 'R8')
# sp_key:  (2009, 'R9')
# sp_key:  (2010, 'R0')
# sp_key:  (2010, 'R1')
# sp_key:  (2010, 'R2')
# sp_key:  (2010, 'R3')
# sp_key:  (2010, 'R4')
# sp_key:  (2010, 'R5')
# sp_key:  (2010, 'R6')
# sp_key:  (2010, 'R7')
# sp_key:  (2010, 'R8')
# sp_key:  (2010, 'R9')
# sp_key:  (2011, 'R0')
# sp_key:  (2011, 'R1')
# sp_key:  (2011, 'R2')
# sp_key:  (2011, 'R3')
# sp_key:  (2011, 'R4')
# sp_key:  (2011, 'R5')
# sp_key:  (2011, 'R6')
# sp_key:  (2011, 'R7')
# sp_key:  (2011, 'R8')
# sp_key:  (2011, 'R9')
# sp_key:  (2012, 'R0')
# sp_key:  (2012, 'R1')
# sp_key:  (2012, 'R2')
# sp_key:  (2012, 'R3')
# sp_key:  (2012, 'R4')
# sp_key:  (2012, 'R5')
# sp_key:  (2012, 'R6')
# sp_key:  (2012, 'R7')
# sp_key:  (2012, 'R8')
# sp_key:  (2012, 'R9')
# sp_key:  (2013, 'R0')
# sp_key:  (2013, 'R1')
# sp_key:  (2013, 'R2')
# sp_key:  (2013, 'R3')
# sp_key:  (2013, 'R4')
# sp_key:  (2013, 'R5')
# sp_key:  (2013, 'R6')
# sp_key:  (2013, 'R7')
# sp_key:  (2013, 'R8')
# sp_key:  (2013, 'R9')
# sp_key:  (2014, 'R0')
# sp_key:  (2014, 'R1')
# sp_key:  (2014, 'R2')
# sp_key:  (2014, 'R3')
# sp_key:  (2014, 'R4')
# sp_key:  (2014, 'R5')
# sp_key:  (2014, 'R6')
# sp_key:  (2014, 'R7')
# sp_key:  (2014, 'R8')
# sp_key:  (2014, 'R9')
# sp_key:  (2015, 'R0')
# sp_key:  (2015, 'R1')
# sp_key:  (2015, 'R2')
# sp_key:  (2015, 'R3')
# sp_key:  (2015, 'R4')
# sp_key:  (2015, 'R5')
# sp_key:  (2015, 'R6')
# sp_key:  (2015, 'R7')
# sp_key:  (2015, 'R8')
# sp_key:  (2015, 'R9')
# sp_key:  (2016, 'R0')
# sp_key:  (2016, 'R1')
# sp_key:  (2016, 'R2')
# sp_key:  (2016, 'R3')
# sp_key:  (2016, 'R4')
# sp_key:  (2016, 'R5')
# sp_key:  (2016, 'R6')
# sp_key:  (2016, 'R7')
# sp_key:  (2016, 'R8')
# sp_key:  (2016, 'R9')
# sp_key:  (2017, 'R0')
# sp_key:  (2017, 'R1')
# sp_key:  (2017, 'R2')
# sp_key:  (2017, 'R3')
# sp_key:  (2017, 'R4')
# sp_key:  (2017, 'R5')
# sp_key:  (2017, 'R6')
# sp_key:  (2017, 'R7')
# sp_key:  (2017, 'R8')
# sp_key:  (2017, 'R9')

# %%
#just download one pic of every movie
#testing the function of try-except is work or now, I add an IMDb ID into the testing file(test_9_image_poster_download.txt)
#the worong number of IMDb ID is 3(in arrary is 2)


CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    print('total number of image: ' , len(urls))
    number_of_poster = len(urls)
    csv_writer.writerow([i+1, list_of_movie_id[i], number_of_poster])
    
    re = requests.get(urls[0])#get the first one pic of url
    def get_first_pic(r, num_i):
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'num{0}.poster.{1}'.format(num_i+1, filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
            print('OK')
        print('now I have downloaded the first movie poster of number', i)
    get_first_pic(re, i)
    
def get_poster_urls(imdbid):
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('test_9_image_poster_download.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    error_list = []
    with open( 'number_of_poster_in_range_test.csv', 'w' , encoding='UTF-8', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        fileHeader = ['num', 'imdb_id' , 'number_of _posters']
        csv_writer.writerow(fileHeader)
        for i in range(0, len(list_of_movie_id)):
            try:
                print('now is the number ' , i+1 , ' : ')
                tmdb_posters(list_of_movie_id[i])
                print('***now the execution have done this time in the local host***')
                print()
            except:
                print('ERROR: CAN NOT not find any pic in ' , i+1)
                error_list.append([i+1, list_of_movie_id[i+1]])
                print()
    print('---FINISHED---')

# %%
error_list[0]

# %%
#download every pics of evrey movie

import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'TOP{0}_poster_{1}.{2}'.format(i, nr+1, filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
        print('now the name of pic is ', filename)
        
def get_poster_urls(imdbid):
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('test_9_image_poster_download.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        print('now is the number ' , i , ' : ')
        tmdb_posters(list_of_movie_id[i])
        print('***now the execution have done this time in the local host***')
    print('---FINISHED---')

# %%
import requests
CONFIG_PATTERN = 'https://api.themoviedb.org/3/authentication/token/new?api_key=e7a9762dabfdc186e180a0791bb06e7c'
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

url = CONFIG_PATTERN.format(key=KEY)
r = requests.get(url)
config = r.json()

# %%
config

# %%
http://api.themoviedb.org/3/movie/<imdbid>/images?api_key=<key>

# %%
import requests
CONFIG_PATTERN = 'https://api.themoviedb.org/3/authentication/token/new?api_key=e7a9762dabfdc186e180a0791bb06e7c'
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

imdb_id = 'tt0384814'
IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdb_id + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
r = requests.get(IMG_PATTERN.format(key=KEY,imdbid=imdb_id))
api_response = r.json()

# %%
len(api_response['backdrops'])

# %%
api_response

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c'
IMG_PATTERN = 'http://api.themoviedb.org/3/movie/tt0468569/images?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'
            
def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """

    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'top4_poster_{0}.{1}'.format(nr+1,filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)

def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'):    
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)

if __name__=="__main__":
    tmdb_posters('tt0468569')

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'
            
def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    count_movie_num = 5 ####cuz i have done the download from 1 to 4
    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'top{0}_poster_{1}.{2}'.format(count_movie_num,  nr+1,filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
    count_movie_num =  count_movie_num + 1

def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('imde_test_top250_id.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        #print('now is the number' + i + ': ')
        tmdb_posters(list_of_movie_id[i])
    print('---FINISHED---')

# %%
f= open('imde_top250_id.txt', encoding = 'utf8')#讀所有詞
s = f.read()
#print(s)
spilt_s = s.split("\n")
spilt_s[1]

# %%
'imde_top250_id.txt'
