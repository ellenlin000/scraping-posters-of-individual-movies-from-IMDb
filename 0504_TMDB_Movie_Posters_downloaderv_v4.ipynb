# %%
import os
import requests
import csv

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    #r = requests.get(url)
    print('total number of image: ' , len(urls))
    number_of_poster = len(urls)
    print(number_of_poster)
    csv_writer.writerow([i, number_of_poster])
    #filetype = r.headers['content-type'].split('/')[-1]
    #filename = 'num{0}.poster.{1}.{2}'.format(i, filetype)
    #filepath = os.path.join(path, filename)
    #with open(filepath,'wb') as w:
        #w.write(r.content)
    print('now I have downloaded the first movie poster of number', i, )
        
def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('test_9_image_poster_download.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    with open( 'number_of_poster_in_range_387_to_395.csv', 'w' , encoding='UTF-8', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        fileHeader = ['num', 'number_of _posters']
        csv_writer.writerow(fileHeader)
        for i in range(0, len(list_of_movie_id)):
            print('now is the number ' , i , ' : ')
            tmdb_posters(list_of_movie_id[i])
            print('***now the execution have done this time in the local host***')
    print('---FINISHED---')
# Out:
# ---STAR---
# ready to get IMDb id from file...
# sucess
# ready to download the movie poster in individual movie...
# now is the number  0  :
# total number of image:  12
# 12
# now I have downloaded the first movie poster of number 0
# ***now the execution have done this time in the local host***
# now is the number  1  :
# total number of image:  11
# 11
# now I have downloaded the first movie poster of number 1
# ***now the execution have done this time in the local host***
# now is the number  2  :
# total number of image:  20
# 20
# now I have downloaded the first movie poster of number 2
# ***now the execution have done this time in the local host***
# now is the number  3  :
# total number of image:  8
# 8
# now I have downloaded the first movie poster of number 3
# ***now the execution have done this time in the local host***
# now is the number  4  :
# total number of image:  20
# 20
# now I have downloaded the first movie poster of number 4
# ***now the execution have done this time in the local host***
# now is the number  5  :
# total number of image:  15
# 15
# now I have downloaded the first movie poster of number 5
# ***now the execution have done this time in the local host***
# now is the number  6  :
# total number of image:  19
# 19
# now I have downloaded the first movie poster of number 6
# ***now the execution have done this time in the local host***
# now is the number  7  :
# total number of image:  16
# 16
# now I have downloaded the first movie poster of number 7
# ***now the execution have done this time in the local host***
# now is the number  8  :
# total number of image:  22
# 22
# now I have downloaded the first movie poster of number 8
# ***now the execution have done this time in the local host***
# ---FINISHED---

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    for nr, url in enumerate(urls):
        r = requests.get(url)
        print('r: ', nr, ', url', url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'TOP{0}_poster_{1}.{2}'.format(i, nr+1, filetype)
        filepath = os.path.join(path, filename)
        print('filepath: ', filepath)
        with open(filepath,'wb') as w:
            w.write(r.content)
        print('now the name of file is ', filename)
        
def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('test_9_image_poster_download.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        print('now is the number ' , i , ' : ')
        tmdb_posters(list_of_movie_id[i])
        print('***now the execution have done this time in the local host***')
    print('---FINISHED---')
# Out:
# ---STAR---
# ready to get IMDb id from file...
# sucess
# ready to download the movie poster in individual movie...
# now is the number  0  :
# r:  0 , url http://image.tmdb.org/t/p/original/96LAzRlBdYyajKRZroLnae9qrpX.jpg
# filepath:  ./TOP0_poster_1.jpeg
# now the name of file is  TOP0_poster_1.jpeg
# r:  1 , url http://image.tmdb.org/t/p/original/fZXrtIuncpVFKNVgiPMlYcSTMIW.jpg
# filepath:  ./TOP0_poster_2.jpeg
# now the name of file is  TOP0_poster_2.jpeg
# r:  2 , url http://image.tmdb.org/t/p/original/bYoGYr3WJ0Pn4tsEgEuXH1svUhR.jpg
# filepath:  ./TOP0_poster_3.jpeg
# now the name of file is  TOP0_poster_3.jpeg
# r:  3 , url http://image.tmdb.org/t/p/original/cvRLMlN76fnAHPinfMpXlVBdXwv.jpg
# filepath:  ./TOP0_poster_4.jpeg
# now the name of file is  TOP0_poster_4.jpeg
# r:  4 , url http://image.tmdb.org/t/p/original/tGdt2A7IkDrylJXfeQzVy6OBC26.jpg
# filepath:  ./TOP0_poster_5.jpeg
# now the name of file is  TOP0_poster_5.jpeg
# r:  5 , url http://image.tmdb.org/t/p/original/jWt73bF5AyUwsfrxZgY4KNHFBW5.jpg
# filepath:  ./TOP0_poster_6.jpeg
# now the name of file is  TOP0_poster_6.jpeg
# r:  6 , url http://image.tmdb.org/t/p/original/hwqr3Z7hlf8LfsfBAhpEcTvpzNv.jpg
# filepath:  ./TOP0_poster_7.jpeg
# now the name of file is  TOP0_poster_7.jpeg
# r:  7 , url http://image.tmdb.org/t/p/original/aPbR3auoJJ7cvOofQGw4NWm7OTf.jpg
# filepath:  ./TOP0_poster_8.jpeg
# now the name of file is  TOP0_poster_8.jpeg
# r:  8 , url http://image.tmdb.org/t/p/original/7XSRPsGNy5Fl3qOcueH5YNT1ELy.jpg
# filepath:  ./TOP0_poster_9.jpeg
# now the name of file is  TOP0_poster_9.jpeg
# r:  9 , url http://image.tmdb.org/t/p/original/hCMtmsEeNk14eCnJwkNcvfLLI86.jpg
# filepath:  ./TOP0_poster_10.jpeg
# now the name of file is  TOP0_poster_10.jpeg
# r:  10 , url http://image.tmdb.org/t/p/original/wr7FTZcO2t86ZifW2Gn952iOwOM.jpg
# filepath:  ./TOP0_poster_11.jpeg
# now the name of file is  TOP0_poster_11.jpeg
# r:  11 , url http://image.tmdb.org/t/p/original/gBGFcX3TMRkyTL2gx4WMlLWoBPK.jpg
# filepath:  ./TOP0_poster_12.jpeg
# now the name of file is  TOP0_poster_12.jpeg
# ***now the execution have done this time in the local host***
# now is the number  1  :
# r:  0 , url http://image.tmdb.org/t/p/original/AvD7oAOit8FZYG1fH2GA5SPLDst.jpg
# filepath:  ./TOP1_poster_1.jpeg
# now the name of file is  TOP1_poster_1.jpeg
# r:  1 , url http://image.tmdb.org/t/p/original/PayQwjnWFJLMbSllV2Gq1kkQs8.jpg
# filepath:  ./TOP1_poster_2.jpeg
# now the name of file is  TOP1_poster_2.jpeg
# r:  2 , url http://image.tmdb.org/t/p/original/iTOxCChcDLv56togZOxF5LK8EkX.jpg
# filepath:  ./TOP1_poster_3.jpeg
# now the name of file is  TOP1_poster_3.jpeg
# r:  3 , url http://image.tmdb.org/t/p/original/krKnsfvSJM1PL40tLicRhVQ6kuG.jpg
# filepath:  ./TOP1_poster_4.jpeg
# now the name of file is  TOP1_poster_4.jpeg
# r:  4 , url http://image.tmdb.org/t/p/original/jSzeMgkfXSyI6eucUIMhcm9LUjB.jpg
# filepath:  ./TOP1_poster_5.jpeg
# now the name of file is  TOP1_poster_5.jpeg
# r:  5 , url http://image.tmdb.org/t/p/original/81nQKJWCC2Sp4igIkSq0xAfpLbt.jpg
# filepath:  ./TOP1_poster_6.jpeg
# now the name of file is  TOP1_poster_6.jpeg
# r:  6 , url http://image.tmdb.org/t/p/original/aZTCObNZQG6TKaMxWNAy2CmMELd.jpg
# filepath:  ./TOP1_poster_7.jpeg
# now the name of file is  TOP1_poster_7.jpeg
# r:  7 , url http://image.tmdb.org/t/p/original/kwIUsDZgP3JUqWEuk5X3lt5XzBi.jpg
# filepath:  ./TOP1_poster_8.jpeg
# now the name of file is  TOP1_poster_8.jpeg
# r:  8 , url http://image.tmdb.org/t/p/original/dB0RwYEE8QFWZ1CfbmYgfUVr8ds.jpg
# filepath:  ./TOP1_poster_9.jpeg
# now the name of file is  TOP1_poster_9.jpeg
# r:  9 , url http://image.tmdb.org/t/p/original/5zKXQt1NDaVKXCfYduNDdALewYX.jpg
# filepath:  ./TOP1_poster_10.jpeg
# now the name of file is  TOP1_poster_10.jpeg
# r:  10 , url http://image.tmdb.org/t/p/original/c0y8RWeyAalBsMFigZU2BPqbu9B.jpg
# filepath:  ./TOP1_poster_11.jpeg
# now the name of file is  TOP1_poster_11.jpeg
# ***now the execution have done this time in the local host***
# now is the number  2  :
# r:  0 , url http://image.tmdb.org/t/p/original/obHJeOHn8J5XD049nj7KVSpAMEW.jpg
# filepath:  ./TOP2_poster_1.jpeg
# now the name of file is  TOP2_poster_1.jpeg
# r:  1 , url http://image.tmdb.org/t/p/original/ozQ37SvbaILHituYurYLwWt4H7P.jpg
# filepath:  ./TOP2_poster_2.jpeg
# now the name of file is  TOP2_poster_2.jpeg
# r:  2 , url http://image.tmdb.org/t/p/original/rIVCA3Vm28IKSoXXOwhicxPitYk.jpg
# filepath:  ./TOP2_poster_3.jpeg
# now the name of file is  TOP2_poster_3.jpeg
# r:  3 , url http://image.tmdb.org/t/p/original/bFZy5aeT1v2G2hwdtw8PHic9iei.jpg
# filepath:  ./TOP2_poster_4.jpeg
# now the name of file is  TOP2_poster_4.jpeg
# r:  4 , url http://image.tmdb.org/t/p/original/llPSFUM3y9J5PLaA302ivV2NO7I.jpg
# filepath:  ./TOP2_poster_5.jpeg
# now the name of file is  TOP2_poster_5.jpeg
# r:  5 , url http://image.tmdb.org/t/p/original/klylgWJBzXCvoNXuYrAV1yXzfMd.jpg
# filepath:  ./TOP2_poster_6.jpeg
# now the name of file is  TOP2_poster_6.jpeg
# r:  6 , url http://image.tmdb.org/t/p/original/gj7c4x4cuO5Wsxt5zFJLHkgKFPw.jpg
# filepath:  ./TOP2_poster_7.jpeg
# now the name of file is  TOP2_poster_7.jpeg
# r:  7 , url http://image.tmdb.org/t/p/original/2StSzonb1qUj54svb8bOYPVxRy1.jpg
# filepath:  ./TOP2_poster_8.jpeg
# now the name of file is  TOP2_poster_8.jpeg
# r:  8 , url http://image.tmdb.org/t/p/original/A2NS4IlpyfYNVx3rX6nU1GhpSf6.jpg
# filepath:  ./TOP2_poster_9.jpeg
# now the name of file is  TOP2_poster_9.jpeg
# r:  9 , url http://image.tmdb.org/t/p/original/brV7gKmyEReorvsnuCLtYfdRcQO.jpg
# filepath:  ./TOP2_poster_10.jpeg
# now the name of file is  TOP2_poster_10.jpeg
# r:  10 , url http://image.tmdb.org/t/p/original/o0VvFCMMdeAhvYwtFEsUsKXauKg.jpg
# filepath:  ./TOP2_poster_11.jpeg
# now the name of file is  TOP2_poster_11.jpeg
# r:  11 , url http://image.tmdb.org/t/p/original/sJe0D5VpCkoeSvSwqTTqVRcZiFk.jpg
# filepath:  ./TOP2_poster_12.jpeg
# now the name of file is  TOP2_poster_12.jpeg
# r:  12 , url http://image.tmdb.org/t/p/original/mO8kqLMTwwgvibpsPBeUOGgFcfS.jpg
# filepath:  ./TOP2_poster_13.jpeg
# now the name of file is  TOP2_poster_13.jpeg
# r:  13 , url http://image.tmdb.org/t/p/original/ovZylXHtMC7eIvacgfBG0mkhd23.jpg
# filepath:  ./TOP2_poster_14.jpeg
# now the name of file is  TOP2_poster_14.jpeg
# r:  14 , url http://image.tmdb.org/t/p/original/8ZmrgnBZRoHXVAOjsUqSiu3GkXR.jpg
# filepath:  ./TOP2_poster_15.jpeg
# now the name of file is  TOP2_poster_15.jpeg
# r:  15 , url http://image.tmdb.org/t/p/original/qlg9xVAOnxVuMLyIrVsvAMptfwC.jpg
# filepath:  ./TOP2_poster_16.jpeg
# now the name of file is  TOP2_poster_16.jpeg
# r:  16 , url http://image.tmdb.org/t/p/original/hiu45JaNPU5hitFab64aos67lvz.jpg
# filepath:  ./TOP2_poster_17.jpeg
# now the name of file is  TOP2_poster_17.jpeg
# r:  17 , url http://image.tmdb.org/t/p/original/3CzgurXHbB7713Aa0w2JPyf5FsL.jpg
# filepath:  ./TOP2_poster_18.jpeg
# now the name of file is  TOP2_poster_18.jpeg
# r:  18 , url http://image.tmdb.org/t/p/original/nS1oPKH826zIpLJ1pkvcvbaQ7xc.jpg
# filepath:  ./TOP2_poster_19.jpeg
# now the name of file is  TOP2_poster_19.jpeg
# r:  19 , url http://image.tmdb.org/t/p/original/7rIzSi5SCQaw2QU95i7VFJxwRH7.jpg
# filepath:  ./TOP2_poster_20.jpeg
# now the name of file is  TOP2_poster_20.jpeg
# ***now the execution have done this time in the local host***
# now is the number  3  :
# r:  0 , url http://image.tmdb.org/t/p/original/yGATBaHRKwQOEkHWMXf80Rd9pnT.jpg
# filepath:  ./TOP3_poster_1.jpeg
# now the name of file is  TOP3_poster_1.jpeg
# r:  1 , url http://image.tmdb.org/t/p/original/urMW0HRHQ14UaygyWzkhi1MAxlU.jpg
# filepath:  ./TOP3_poster_2.jpeg
# now the name of file is  TOP3_poster_2.jpeg
# r:  2 , url http://image.tmdb.org/t/p/original/9PAPoSOERCLgLGlRbU6hOBuWSwg.jpg
# filepath:  ./TOP3_poster_3.jpeg
# now the name of file is  TOP3_poster_3.jpeg
# r:  3 , url http://image.tmdb.org/t/p/original/hWTXIeyxNPY9dgBYcAomu0FHTS2.jpg
# filepath:  ./TOP3_poster_4.jpeg
# now the name of file is  TOP3_poster_4.jpeg
# r:  4 , url http://image.tmdb.org/t/p/original/kmM08MutwLcnMJmQpwxcRMOwD34.jpg
# filepath:  ./TOP3_poster_5.jpeg
# now the name of file is  TOP3_poster_5.jpeg
# r:  5 , url http://image.tmdb.org/t/p/original/oQCYzqeiH6amaI60I5NhL8FPD6F.jpg
# filepath:  ./TOP3_poster_6.jpeg
# now the name of file is  TOP3_poster_6.jpeg
# r:  6 , url http://image.tmdb.org/t/p/original/y49oCIUEK2IMsC3XrS2vxeBpvYk.jpg
# filepath:  ./TOP3_poster_7.jpeg
# now the name of file is  TOP3_poster_7.jpeg
# r:  7 , url http://image.tmdb.org/t/p/original/dfMk50EejobFjvg2LO3HGa2GfHE.jpg
# filepath:  ./TOP3_poster_8.jpeg
# now the name of file is  TOP3_poster_8.jpeg
# ***now the execution have done this time in the local host***
# now is the number  4  :
# r:  0 , url http://image.tmdb.org/t/p/original/gOZbRtcLCgDARcIkc6Zv2P1UDti.jpg
# filepath:  ./TOP4_poster_1.jpeg
# now the name of file is  TOP4_poster_1.jpeg
# r:  1 , url http://image.tmdb.org/t/p/original/kUdYgnKkCNJ4aak6Ivy6IdlIElL.jpg
# filepath:  ./TOP4_poster_2.jpeg
# now the name of file is  TOP4_poster_2.jpeg
# r:  2 , url http://image.tmdb.org/t/p/original/gHaOm49i7HcgiP9GmXrxtYnB8DC.jpg
# filepath:  ./TOP4_poster_3.jpeg
# now the name of file is  TOP4_poster_3.jpeg
# r:  3 , url http://image.tmdb.org/t/p/original/cFVmwdtxu5usdmcX4Nn0nHKERZv.jpg
# filepath:  ./TOP4_poster_4.jpeg
# now the name of file is  TOP4_poster_4.jpeg
# r:  4 , url http://image.tmdb.org/t/p/original/ornExP9x09gOTxeENb7vsYwrsj1.jpg
# filepath:  ./TOP4_poster_5.jpeg
# now the name of file is  TOP4_poster_5.jpeg

# %%
import requests
CONFIG_PATTERN = 'https://api.themoviedb.org/3/authentication/token/new?api_key=e7a9762dabfdc186e180a0791bb06e7c'
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

url = CONFIG_PATTERN.format(key=KEY)
r = requests.get(url)
config = r.json()

# %%
config

# %%
http://api.themoviedb.org/3/movie/<imdbid>/images?api_key=<key>

# %%
import requests
CONFIG_PATTERN = 'https://api.themoviedb.org/3/authentication/token/new?api_key=e7a9762dabfdc186e180a0791bb06e7c'
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

IMG_PATTERN = 'http://api.themoviedb.org/3/movie/tt0095016/images?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
r = requests.get(IMG_PATTERN.format(key=KEY,imdbid='tt0095016'))
api_response = r.json()

# %%
api_response

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c'
IMG_PATTERN = 'http://api.themoviedb.org/3/movie/tt0468569/images?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'
            
def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """

    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'top4_poster_{0}.{1}'.format(nr+1,filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)

def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'):    
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)

if __name__=="__main__":
    tmdb_posters('tt0468569')

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'
            
def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    count_movie_num = 5 ####cuz i have done the download from 1 to 4
    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'top{0}_poster_{1}.{2}'.format(count_movie_num,  nr+1,filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
    count_movie_num =  count_movie_num + 1

def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('imde_test_top250_id.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        #print('now is the number' + i + ': ')
        tmdb_posters(list_of_movie_id[i])
    print('---FINISHED---')

# %%
f= open('imde_top250_id.txt', encoding = 'utf8')#讀所有詞
s = f.read()
#print(s)
spilt_s = s.split("\n")
spilt_s[1]

# %%
'imde_top250_id.txt'
