# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'middle.{0}.{1}.{2}'.format(i, nr+1, filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
        print('now the name of file is ', filename)
        
def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('middle_100.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        print('now is the number ' , i , ' : ')
        tmdb_posters(list_of_movie_id[i])
        print('***now the execution have done this time in the local host***')
    print('---FINISHED---')
# Out:
# ---STAR---
# ready to get IMDb id from file...
# sucess
# ready to download the movie poster in individual movie...
# now is the number  0  :
# now the name of file is  middle.0.1.jpeg
# now the name of file is  middle.0.2.jpeg
# now the name of file is  middle.0.3.jpeg
# now the name of file is  middle.0.4.jpeg
# now the name of file is  middle.0.5.jpeg
# now the name of file is  middle.0.6.jpeg
# now the name of file is  middle.0.7.jpeg
# now the name of file is  middle.0.8.jpeg
# now the name of file is  middle.0.9.jpeg
# now the name of file is  middle.0.10.jpeg
# now the name of file is  middle.0.11.jpeg
# now the name of file is  middle.0.12.jpeg
# now the name of file is  middle.0.13.jpeg
# now the name of file is  middle.0.14.jpeg
# now the name of file is  middle.0.15.jpeg
# now the name of file is  middle.0.16.jpeg
# now the name of file is  middle.0.17.jpeg
# now the name of file is  middle.0.18.jpeg
# now the name of file is  middle.0.19.jpeg
# now the name of file is  middle.0.20.jpeg
# now the name of file is  middle.0.21.jpeg
# now the name of file is  middle.0.22.jpeg
# now the name of file is  middle.0.23.jpeg
# now the name of file is  middle.0.24.jpeg
# now the name of file is  middle.0.25.jpeg
# now the name of file is  middle.0.26.jpeg
# now the name of file is  middle.0.27.jpeg
# now the name of file is  middle.0.28.jpeg
# now the name of file is  middle.0.29.jpeg
# now the name of file is  middle.0.30.jpeg
# now the name of file is  middle.0.31.jpeg
# now the name of file is  middle.0.32.jpeg
# now the name of file is  middle.0.33.jpeg
# now the name of file is  middle.0.34.jpeg
# now the name of file is  middle.0.35.jpeg
# now the name of file is  middle.0.36.jpeg
# now the name of file is  middle.0.37.jpeg
# now the name of file is  middle.0.38.jpeg
# now the name of file is  middle.0.39.jpeg
# now the name of file is  middle.0.40.jpeg
# now the name of file is  middle.0.41.jpeg
# now the name of file is  middle.0.42.jpeg
# now the name of file is  middle.0.43.jpeg
# now the name of file is  middle.0.44.jpeg
# now the name of file is  middle.0.45.jpeg
# now the name of file is  middle.0.46.jpeg
# now the name of file is  middle.0.47.jpeg
# now the name of file is  middle.0.48.jpeg
# now the name of file is  middle.0.49.jpeg
# now the name of file is  middle.0.50.jpeg
# now the name of file is  middle.0.51.jpeg
# ***now the execution have done this time in the local host***
# now is the number  1  :
# now the name of file is  middle.1.1.jpeg
# now the name of file is  middle.1.2.jpeg
# now the name of file is  middle.1.3.jpeg
# now the name of file is  middle.1.4.jpeg
# now the name of file is  middle.1.5.jpeg
# now the name of file is  middle.1.6.jpeg
# now the name of file is  middle.1.7.jpeg
# now the name of file is  middle.1.8.jpeg
# now the name of file is  middle.1.9.jpeg
# now the name of file is  middle.1.10.jpeg
# now the name of file is  middle.1.11.jpeg
# now the name of file is  middle.1.12.jpeg
# now the name of file is  middle.1.13.jpeg
# now the name of file is  middle.1.14.jpeg
# now the name of file is  middle.1.15.jpeg
# now the name of file is  middle.1.16.jpeg
# now the name of file is  middle.1.17.jpeg
# now the name of file is  middle.1.18.jpeg
# now the name of file is  middle.1.19.jpeg
# now the name of file is  middle.1.20.jpeg
# now the name of file is  middle.1.21.jpeg
# now the name of file is  middle.1.22.jpeg
# now the name of file is  middle.1.23.jpeg
# now the name of file is  middle.1.24.jpeg
# ***now the execution have done this time in the local host***
# now is the number  2  :
# now the name of file is  middle.2.1.jpeg
# now the name of file is  middle.2.2.jpeg
# now the name of file is  middle.2.3.jpeg
# now the name of file is  middle.2.4.jpeg
# now the name of file is  middle.2.5.jpeg
# now the name of file is  middle.2.6.jpeg
# now the name of file is  middle.2.7.jpeg
# now the name of file is  middle.2.8.jpeg
# now the name of file is  middle.2.9.jpeg
# now the name of file is  middle.2.10.jpeg
# now the name of file is  middle.2.11.jpeg
# now the name of file is  middle.2.12.jpeg
# now the name of file is  middle.2.13.jpeg
# now the name of file is  middle.2.14.jpeg
# now the name of file is  middle.2.15.jpeg
# now the name of file is  middle.2.16.jpeg
# now the name of file is  middle.2.17.jpeg
# now the name of file is  middle.2.18.jpeg
# now the name of file is  middle.2.19.jpeg
# now the name of file is  middle.2.20.jpeg
# now the name of file is  middle.2.21.jpeg
# now the name of file is  middle.2.22.jpeg
# now the name of file is  middle.2.23.jpeg
# now the name of file is  middle.2.24.jpeg
# now the name of file is  middle.2.25.jpeg
# now the name of file is  middle.2.26.jpeg
# now the name of file is  middle.2.27.jpeg
# now the name of file is  middle.2.28.jpeg
# now the name of file is  middle.2.29.jpeg
# now the name of file is  middle.2.30.jpeg
# now the name of file is  middle.2.31.jpeg
# now the name of file is  middle.2.32.jpeg
# now the name of file is  middle.2.33.jpeg
# now the name of file is  middle.2.34.jpeg
# now the name of file is  middle.2.35.jpeg
# now the name of file is  middle.2.36.jpeg
# now the name of file is  middle.2.37.jpeg
# now the name of file is  middle.2.38.jpeg
# now the name of file is  middle.2.39.jpeg
# now the name of file is  middle.2.40.jpeg
# now the name of file is  middle.2.41.jpeg
# now the name of file is  middle.2.42.jpeg
# now the name of file is  middle.2.43.jpeg
# now the name of file is  middle.2.44.jpeg
# now the name of file is  middle.2.45.jpeg
# now the name of file is  middle.2.46.jpeg
# now the name of file is  middle.2.47.jpeg
# now the name of file is  middle.2.48.jpeg
# now the name of file is  middle.2.49.jpeg
# now the name of file is  middle.2.50.jpeg
# now the name of file is  middle.2.51.jpeg
# now the name of file is  middle.2.52.jpeg
# now the name of file is  middle.2.53.jpeg
# now the name of file is  middle.2.54.jpeg
# now the name of file is  middle.2.55.jpeg
# now the name of file is  middle.2.56.jpeg
# now the name of file is  middle.2.57.jpeg
# now the name of file is  middle.2.58.jpeg
# now the name of file is  middle.2.59.jpeg
# now the name of file is  middle.2.60.jpeg
# now the name of file is  middle.2.61.jpeg
# now the name of file is  middle.2.62.jpeg
# now the name of file is  middle.2.63.jpeg
# now the name of file is  middle.2.64.jpeg
# now the name of file is  middle.2.65.jpeg
# now the name of file is  middle.2.66.jpeg
# now the name of file is  middle.2.67.jpeg
# now the name of file is  middle.2.68.jpeg
# now the name of file is  middle.2.69.jpeg
# now the name of file is  middle.2.70.jpeg
# now the name of file is  middle.2.71.jpeg
# now the name of file is  middle.2.72.jpeg
# now the name of file is  middle.2.73.jpeg
# now the name of file is  middle.2.74.jpeg
# now the name of file is  middle.2.75.jpeg
# now the name of file is  middle.2.76.jpeg
# now the name of file is  middle.2.77.jpeg
# now the name of file is  middle.2.78.jpeg
# now the name of file is  middle.2.79.jpeg
# now the name of file is  middle.2.80.jpeg
# now the name of file is  middle.2.81.jpeg
# now the name of file is  middle.2.82.jpeg
# now the name of file is  middle.2.83.jpeg
# now the name of file is  middle.2.84.jpeg
# now the name of file is  middle.2.85.jpeg
# now the name of file is  middle.2.86.jpeg
# now the name of file is  middle.2.87.jpeg
# now the name of file is  middle.2.88.jpeg
# now the name of file is  middle.2.89.jpeg
# now the name of file is  middle.2.90.jpeg
# now the name of file is  middle.2.91.jpeg
# now the name of file is  middle.2.92.jpeg
# now the name of file is  middle.2.93.jpeg
# now the name of file is  middle.2.94.jpeg
# now the name of file is  middle.2.95.jpeg
# now the name of file is  middle.2.96.jpeg
# now the name of file is  middle.2.97.jpeg
# now the name of file is  middle.2.98.jpeg
# now the name of file is  middle.2.99.jpeg
# now the name of file is  middle.2.100.jpeg
# now the name of file is  middle.2.101.jpeg
# now the name of file is  middle.2.102.jpeg
# now the name of file is  middle.2.103.jpeg
# now the name of file is  middle.2.104.jpeg
# now the name of file is  middle.2.105.jpeg
# now the name of file is  middle.2.106.jpeg
# now the name of file is  middle.2.107.jpeg
# now the name of file is  middle.2.108.jpeg
# now the name of file is  middle.2.109.jpeg
# now the name of file is  middle.2.110.jpeg
# now the name of file is  middle.2.111.jpeg
# ***now the execution have done this time in the local host***
# now is the number  3  :
# now the name of file is  middle.3.1.jpeg
# now the name of file is  middle.3.2.jpeg
# now the name of file is  middle.3.3.jpeg
# now the name of file is  middle.3.4.jpeg
# now the name of file is  middle.3.5.jpeg
# now the name of file is  middle.3.6.jpeg
# now the name of file is  middle.3.7.jpeg
# now the name of file is  middle.3.8.jpeg
# now the name of file is  middle.3.9.jpeg
# now the name of file is  middle.3.10.jpeg
# now the name of file is  middle.3.11.jpeg
# now the name of file is  middle.3.12.jpeg
# now the name of file is  middle.3.13.jpeg
# now the name of file is  middle.3.14.jpeg
# now the name of file is  middle.3.15.jpeg
# now the name of file is  middle.3.16.jpeg
# now the name of file is  middle.3.17.jpeg
# now the name of file is  middle.3.18.jpeg
# now the name of file is  middle.3.19.jpeg
# now the name of file is  middle.3.20.jpeg
# now the name of file is  middle.3.21.jpeg
# now the name of file is  middle.3.22.jpeg
# now the name of file is  middle.3.23.jpeg
# now the name of file is  middle.3.24.jpeg
# now the name of file is  middle.3.25.jpeg
# now the name of file is  middle.3.26.jpeg
# now the name of file is  middle.3.27.jpeg
# now the name of file is  middle.3.28.jpeg
# now the name of file is  middle.3.29.jpeg
# now the name of file is  middle.3.30.jpeg
# now the name of file is  middle.3.31.jpeg
# now the name of file is  middle.3.32.jpeg
# now the name of file is  middle.3.33.jpeg
# now the name of file is  middle.3.34.jpeg
# now the name of file is  middle.3.35.jpeg
# now the name of file is  middle.3.36.jpeg
# now the name of file is  middle.3.37.jpeg
# now the name of file is  middle.3.38.jpeg
# now the name of file is  middle.3.39.jpeg
# now the name of file is  middle.3.40.jpeg
# now the name of file is  middle.3.41.jpeg
# now the name of file is  middle.3.42.jpeg
# now the name of file is  middle.3.43.jpeg
# now the name of file is  middle.3.44.jpeg
# now the name of file is  middle.3.45.jpeg
# now the name of file is  middle.3.46.jpeg
# now the name of file is  middle.3.47.jpeg
# now the name of file is  middle.3.48.jpeg
# now the name of file is  middle.3.49.jpeg
# now the name of file is  middle.3.50.jpeg
# now the name of file is  middle.3.51.jpeg
# now the name of file is  middle.3.52.jpeg
# now the name of file is  middle.3.53.jpeg
# now the name of file is  middle.3.54.jpeg
# now the name of file is  middle.3.55.jpeg
# now the name of file is  middle.3.56.jpeg
# now the name of file is  middle.3.57.jpeg
# now the name of file is  middle.3.58.jpeg
# now the name of file is  middle.3.59.jpeg
# now the name of file is  middle.3.60.jpeg
# now the name of file is  middle.3.61.jpeg
# now the name of file is  middle.3.62.jpeg
# now the name of file is  middle.3.63.jpeg
# now the name of file is  middle.3.64.jpeg
# now the name of file is  middle.3.65.jpeg
# now the name of file is  middle.3.66.jpeg
# now the name of file is  middle.3.67.jpeg
# now the name of file is  middle.3.68.jpeg
# now the name of file is  middle.3.69.jpeg
# now the name of file is  middle.3.70.jpeg
# now the name of file is  middle.3.71.jpeg
# now the name of file is  middle.3.72.jpeg
# now the name of file is  middle.3.73.jpeg
# now the name of file is  middle.3.74.jpeg
# now the name of file is  middle.3.75.jpeg
# now the name of file is  middle.3.76.jpeg
# now the name of file is  middle.3.77.jpeg
# now the name of file is  middle.3.78.jpeg
# now the name of file is  middle.3.79.jpeg
# now the name of file is  middle.3.80.jpeg
# now the name of file is  middle.3.81.jpeg
# now the name of file is  middle.3.82.jpeg
# now the name of file is  middle.3.83.jpeg
# now the name of file is  middle.3.84.jpeg
# now the name of file is  middle.3.85.jpeg
# now the name of file is  middle.3.86.jpeg
# now the name of file is  middle.3.87.jpeg
# now the name of file is  middle.3.88.jpeg
# now the name of file is  middle.3.89.jpeg
# ***now the execution have done this time in the local host***
# now is the number  4  :
# now the name of file is  middle.4.1.jpeg
# now the name of file is  middle.4.2.jpeg
# now the name of file is  middle.4.3.jpeg
# now the name of file is  middle.4.4.jpeg
# now the name of file is  middle.4.5.jpeg
# now the name of file is  middle.4.6.jpeg
# now the name of file is  middle.4.7.jpeg
# now the name of file is  middle.4.8.jpeg
# now the name of file is  middle.4.9.jpeg
# now the name of file is  middle.4.10.jpeg
# ***now the execution have done this time in the local host***
# now is the number  5  :
# now the name of file is  middle.5.1.jpeg
# now the name of file is  middle.5.2.jpeg
# now the name of file is  middle.5.3.jpeg
# now the name of file is  middle.5.4.jpeg
# now the name of file is  middle.5.5.jpeg
# now the name of file is  middle.5.6.jpeg
# now the name of file is  middle.5.7.jpeg
# now the name of file is  middle.5.8.jpeg
# now the name of file is  middle.5.9.jpeg
# now the name of file is  middle.5.10.jpeg
# now the name of file is  middle.5.11.jpeg
# now the name of file is  middle.5.12.jpeg
# now the name of file is  middle.5.13.jpeg
# now the name of file is  middle.5.14.jpeg
# now the name of file is  middle.5.15.jpeg
# now the name of file is  middle.5.16.jpeg
# now the name of file is  middle.5.17.jpeg
# now the name of file is  middle.5.18.jpeg
# now the name of file is  middle.5.19.jpeg
# now the name of file is  middle.5.20.jpeg
# now the name of file is  middle.5.21.jpeg
# now the name of file is  middle.5.22.jpeg
# now the name of file is  middle.5.23.jpeg
# now the name of file is  middle.5.24.jpeg
# now the name of file is  middle.5.25.jpeg
# now the name of file is  middle.5.26.jpeg
# now the name of file is  middle.5.27.jpeg
# now the name of file is  middle.5.28.jpeg
# now the name of file is  middle.5.29.jpeg
# now the name of file is  middle.5.30.jpeg
# now the name of file is  middle.5.31.jpeg
# now the name of file is  middle.5.32.jpeg
# now the name of file is  middle.5.33.jpeg
# now the name of file is  middle.5.34.jpeg
# now the name of file is  middle.5.35.jpeg
# now the name of file is  middle.5.36.jpeg
# now the name of file is  middle.5.37.jpeg
# now the name of file is  middle.5.38.jpeg
# now the name of file is  middle.5.39.jpeg
# now the name of file is  middle.5.40.jpeg
# now the name of file is  middle.5.41.jpeg
# now the name of file is  middle.5.42.jpeg
# now the name of file is  middle.5.43.jpeg
# now the name of file is  middle.5.44.jpeg
# now the name of file is  middle.5.45.jpeg
# now the name of file is  middle.5.46.jpeg
# now the name of file is  middle.5.47.jpeg
# now the name of file is  middle.5.48.jpeg
# now the name of file is  middle.5.49.jpeg
# now the name of file is  middle.5.50.jpeg
# now the name of file is  middle.5.51.jpeg
# now the name of file is  middle.5.52.jpeg
# now the name of file is  middle.5.53.jpeg
# now the name of file is  middle.5.54.jpeg
# now the name of file is  middle.5.55.jpeg
# now the name of file is  middle.5.56.jpeg
# now the name of file is  middle.5.57.jpeg
# now the name of file is  middle.5.58.jpeg
# now the name of file is  middle.5.59.jpeg
# now the name of file is  middle.5.60.jpeg
# now the name of file is  middle.5.61.jpeg
# now the name of file is  middle.5.62.jpeg
# now the name of file is  middle.5.63.jpeg
# now the name of file is  middle.5.64.jpeg
# now the name of file is  middle.5.65.jpeg
# now the name of file is  middle.5.66.jpeg
# now the name of file is  middle.5.67.jpeg
# now the name of file is  middle.5.68.jpeg
# now the name of file is  middle.5.69.jpeg
# ***now the execution have done this time in the local host***
# now is the number  6  :
# now the name of file is  middle.6.1.jpeg
# now the name of file is  middle.6.2.jpeg
# now the name of file is  middle.6.3.jpeg
# now the name of file is  middle.6.4.jpeg
# now the name of file is  middle.6.5.jpeg
# now the name of file is  middle.6.6.jpeg
# now the name of file is  middle.6.7.jpeg
# now the name of file is  middle.6.8.jpeg
# now the name of file is  middle.6.9.jpeg
# now the name of file is  middle.6.10.jpeg
# now the name of file is  middle.6.11.jpeg
# now the name of file is  middle.6.12.jpeg
# now the name of file is  middle.6.13.jpeg
# now the name of file is  middle.6.14.jpeg
# now the name of file is  middle.6.15.jpeg
# now the name of file is  middle.6.16.jpeg
# now the name of file is  middle.6.17.jpeg
# now the name of file is  middle.6.18.jpeg
# now the name of file is  middle.6.19.jpeg
# now the name of file is  middle.6.20.jpeg
# now the name of file is  middle.6.21.jpeg
# now the name of file is  middle.6.22.jpeg
# now the name of file is  middle.6.23.jpeg
# now the name of file is  middle.6.24.jpeg
# now the name of file is  middle.6.25.jpeg
# now the name of file is  middle.6.26.jpeg
# now the name of file is  middle.6.27.jpeg
# now the name of file is  middle.6.28.jpeg
# now the name of file is  middle.6.29.jpeg
# now the name of file is  middle.6.30.jpeg
# now the name of file is  middle.6.31.jpeg
# now the name of file is  middle.6.32.jpeg
# now the name of file is  middle.6.33.jpeg
# now the name of file is  middle.6.34.jpeg
# now the name of file is  middle.6.35.jpeg
# now the name of file is  middle.6.36.jpeg
# now the name of file is  middle.6.37.jpeg
# now the name of file is  middle.6.38.jpeg
# now the name of file is  middle.6.39.jpeg
# now the name of file is  middle.6.40.jpeg
# now the name of file is  middle.6.41.jpeg
# now the name of file is  middle.6.42.jpeg
# ***now the execution have done this time in the local host***
# now is the number  7  :
# now the name of file is  middle.7.1.jpeg
# now the name of file is  middle.7.2.jpeg
# now the name of file is  middle.7.3.jpeg
# now the name of file is  middle.7.4.jpeg
# now the name of file is  middle.7.5.jpeg
# now the name of file is  middle.7.6.jpeg
# now the name of file is  middle.7.7.jpeg
# now the name of file is  middle.7.8.jpeg
# now the name of file is  middle.7.9.jpeg
# now the name of file is  middle.7.10.jpeg
# now the name of file is  middle.7.11.jpeg
# now the name of file is  middle.7.12.jpeg
# now the name of file is  middle.7.13.jpeg
# now the name of file is  middle.7.14.jpeg
# now the name of file is  middle.7.15.jpeg
# now the name of file is  middle.7.16.jpeg
# now the name of file is  middle.7.17.jpeg
# now the name of file is  middle.7.18.jpeg
# now the name of file is  middle.7.19.jpeg
# now the name of file is  middle.7.20.jpeg
# now the name of file is  middle.7.21.jpeg
# now the name of file is  middle.7.22.jpeg
# now the name of file is  middle.7.23.jpeg
# now the name of file is  middle.7.24.jpeg
# now the name of file is  middle.7.25.jpeg
# now the name of file is  middle.7.26.jpeg
# now the name of file is  middle.7.27.jpeg
# now the name of file is  middle.7.28.jpeg
# now the name of file is  middle.7.29.jpeg
# now the name of file is  middle.7.30.jpeg
# now the name of file is  middle.7.31.jpeg
# now the name of file is  middle.7.32.jpeg
# now the name of file is  middle.7.33.jpeg
# ***now the execution have done this time in the local host***
# now is the number  8  :
# now the name of file is  middle.8.1.jpeg
# now the name of file is  middle.8.2.jpeg
# now the name of file is  middle.8.3.jpeg
# now the name of file is  middle.8.4.jpeg
# now the name of file is  middle.8.5.jpeg
# now the name of file is  middle.8.6.jpeg
# now the name of file is  middle.8.7.jpeg
# now the name of file is  middle.8.8.jpeg
# now the name of file is  middle.8.9.jpeg
# now the name of file is  middle.8.10.jpeg
# now the name of file is  middle.8.11.jpeg
# now the name of file is  middle.8.12.jpeg
# now the name of file is  middle.8.13.jpeg
# now the name of file is  middle.8.14.jpeg
# now the name of file is  middle.8.15.jpeg
# now the name of file is  middle.8.16.jpeg
# now the name of file is  middle.8.17.jpeg
# now the name of file is  middle.8.18.jpeg
# now the name of file is  middle.8.19.jpeg
# now the name of file is  middle.8.20.jpeg
# now the name of file is  middle.8.21.jpeg
# now the name of file is  middle.8.22.jpeg
# now the name of file is  middle.8.23.jpeg
# now the name of file is  middle.8.24.jpeg
# now the name of file is  middle.8.25.jpeg
# now the name of file is  middle.8.26.jpeg
# now the name of file is  middle.8.27.jpeg
# now the name of file is  middle.8.28.jpeg
# now the name of file is  middle.8.29.jpeg
# now the name of file is  middle.8.30.jpeg
# now the name of file is  middle.8.31.jpeg
# now the name of file is  middle.8.32.jpeg
# now the name of file is  middle.8.33.jpeg
# now the name of file is  middle.8.34.jpeg
# now the name of file is  middle.8.35.jpeg
# now the name of file is  middle.8.36.jpeg
# now the name of file is  middle.8.37.jpeg
# now the name of file is  middle.8.38.jpeg
# now the name of file is  middle.8.39.jpeg
# now the name of file is  middle.8.40.jpeg
# now the name of file is  middle.8.41.jpeg
# now the name of file is  middle.8.42.jpeg
# now the name of file is  middle.8.43.jpeg
# now the name of file is  middle.8.44.jpeg
# now the name of file is  middle.8.45.jpeg
# now the name of file is  middle.8.46.jpeg
# now the name of file is  middle.8.47.jpeg
# now the name of file is  middle.8.48.jpeg
# now the name of file is  middle.8.49.jpeg
# now the name of file is  middle.8.50.jpeg
# now the name of file is  middle.8.51.jpeg
# now the name of file is  middle.8.52.jpeg
# now the name of file is  middle.8.53.jpeg
# ***now the execution have done this time in the local host***
# now is the number  9  :
# now the name of file is  middle.9.1.jpeg
# now the name of file is  middle.9.2.jpeg
# now the name of file is  middle.9.3.jpeg
# now the name of file is  middle.9.4.jpeg
# now the name of file is  middle.9.5.jpeg
# now the name of file is  middle.9.6.jpeg
# now the name of file is  middle.9.7.jpeg
# now the name of file is  middle.9.8.jpeg
# now the name of file is  middle.9.9.jpeg
# now the name of file is  middle.9.10.jpeg
# now the name of file is  middle.9.11.jpeg
# now the name of file is  middle.9.12.jpeg
# now the name of file is  middle.9.13.jpeg
# ***now the execution have done this time in the local host***
# now is the number  10  :
# now the name of file is  middle.10.1.jpeg
# now the name of file is  middle.10.2.jpeg
# now the name of file is  middle.10.3.jpeg
# now the name of file is  middle.10.4.jpeg
# now the name of file is  middle.10.5.jpeg
# now the name of file is  middle.10.6.jpeg
# now the name of file is  middle.10.7.jpeg
# now the name of file is  middle.10.8.jpeg
# now the name of file is  middle.10.9.jpeg
# now the name of file is  middle.10.10.jpeg
# now the name of file is  middle.10.11.jpeg
# now the name of file is  middle.10.12.jpeg
# now the name of file is  middle.10.13.jpeg
# now the name of file is  middle.10.14.jpeg
# now the name of file is  middle.10.15.jpeg
# now the name of file is  middle.10.16.jpeg
# now the name of file is  middle.10.17.jpeg
# ***now the execution have done this time in the local host***
# now is the number  11  :
# now the name of file is  middle.11.1.jpeg
# now the name of file is  middle.11.2.jpeg
# now the name of file is  middle.11.3.jpeg
# now the name of file is  middle.11.4.jpeg
# now the name of file is  middle.11.5.jpeg
# now the name of file is  middle.11.6.jpeg
# now the name of file is  middle.11.7.jpeg
# now the name of file is  middle.11.8.jpeg
# now the name of file is  middle.11.9.jpeg
# now the name of file is  middle.11.10.jpeg
# now the name of file is  middle.11.11.jpeg
# now the name of file is  middle.11.12.jpeg
# now the name of file is  middle.11.13.jpeg
# now the name of file is  middle.11.14.jpeg
# now the name of file is  middle.11.15.jpeg
# now the name of file is  middle.11.16.jpeg
# now the name of file is  middle.11.17.jpeg
# now the name of file is  middle.11.18.jpeg
# now the name of file is  middle.11.19.jpeg
# now the name of file is  middle.11.20.jpeg
# now the name of file is  middle.11.21.jpeg
# now the name of file is  middle.11.22.jpeg
# now the name of file is  middle.11.23.jpeg
# now the name of file is  middle.11.24.jpeg
# now the name of file is  middle.11.25.jpeg
# now the name of file is  middle.11.26.jpeg
# now the name of file is  middle.11.27.jpeg
# now the name of file is  middle.11.28.jpeg
# now the name of file is  middle.11.29.jpeg
# now the name of file is  middle.11.30.jpeg
# now the name of file is  middle.11.31.jpeg
# now the name of file is  middle.11.32.jpeg
# now the name of file is  middle.11.33.jpeg
# now the name of file is  middle.11.34.jpeg
# now the name of file is  middle.11.35.jpeg
# now the name of file is  middle.11.36.jpeg
# now the name of file is  middle.11.37.jpeg
# now the name of file is  middle.11.38.jpeg
# now the name of file is  middle.11.39.jpeg
# now the name of file is  middle.11.40.jpeg
# now the name of file is  middle.11.41.jpeg
# now the name of file is  middle.11.42.jpeg
# now the name of file is  middle.11.43.jpeg
# now the name of file is  middle.11.44.jpeg
# now the name of file is  middle.11.45.jpeg
# now the name of file is  middle.11.46.jpeg
# now the name of file is  middle.11.47.jpeg
# now the name of file is  middle.11.48.jpeg
# now the name of file is  middle.11.49.jpeg
# now the name of file is  middle.11.50.jpeg
# now the name of file is  middle.11.51.jpeg
# now the name of file is  middle.11.52.jpeg
# now the name of file is  middle.11.53.jpeg
# now the name of file is  middle.11.54.jpeg
# now the name of file is  middle.11.55.jpeg
# now the name of file is  middle.11.56.jpeg
# now the name of file is  middle.11.57.jpeg
# now the name of file is  middle.11.58.jpeg
# now the name of file is  middle.11.59.jpeg
# now the name of file is  middle.11.60.jpeg
# now the name of file is  middle.11.61.jpeg
# now the name of file is  middle.11.62.jpeg
# now the name of file is  middle.11.63.jpeg
# now the name of file is  middle.11.64.jpeg
# now the name of file is  middle.11.65.jpeg
# now the name of file is  middle.11.66.jpeg
# now the name of file is  middle.11.67.jpeg
# now the name of file is  middle.11.68.jpeg
# now the name of file is  middle.11.69.jpeg
# now the name of file is  middle.11.70.jpeg
# now the name of file is  middle.11.71.jpeg
# now the name of file is  middle.11.72.jpeg
# now the name of file is  middle.11.73.jpeg
# now the name of file is  middle.11.74.jpeg
# now the name of file is  middle.11.75.jpeg
# now the name of file is  middle.11.76.jpeg
# now the name of file is  middle.11.77.jpeg
# now the name of file is  middle.11.78.jpeg
# now the name of file is  middle.11.79.jpeg
# now the name of file is  middle.11.80.jpeg
# now the name of file is  middle.11.81.jpeg
# now the name of file is  middle.11.82.jpeg
# now the name of file is  middle.11.83.jpeg
# now the name of file is  middle.11.84.jpeg
# now the name of file is  middle.11.85.jpeg
# now the name of file is  middle.11.86.jpeg
# now the name of file is  middle.11.87.jpeg
# now the name of file is  middle.11.88.jpeg
# now the name of file is  middle.11.89.jpeg
# now the name of file is  middle.11.90.jpeg
# now the name of file is  middle.11.91.jpeg
# now the name of file is  middle.11.92.jpeg
# now the name of file is  middle.11.93.jpeg
# now the name of file is  middle.11.94.jpeg
# now the name of file is  middle.11.95.jpeg
# now the name of file is  middle.11.96.jpeg
# now the name of file is  middle.11.97.jpeg
# now the name of file is  middle.11.98.jpeg
# now the name of file is  middle.11.99.jpeg
# now the name of file is  middle.11.100.jpeg
# now the name of file is  middle.11.101.jpeg
# now the name of file is  middle.11.102.jpeg
# now the name of file is  middle.11.103.jpeg
# now the name of file is  middle.11.104.jpeg
# now the name of file is  middle.11.105.jpeg
# now the name of file is  middle.11.106.jpeg
# now the name of file is  middle.11.107.jpeg
# now the name of file is  middle.11.108.jpeg
# now the name of file is  middle.11.109.jpeg
# now the name of file is  middle.11.110.jpeg
# now the name of file is  middle.11.111.jpeg
# now the name of file is  middle.11.112.jpeg
# now the name of file is  middle.11.113.jpeg
# now the name of file is  middle.11.114.jpeg
# now the name of file is  middle.11.115.jpeg
# now the name of file is  middle.11.116.jpeg
# now the name of file is  middle.11.117.jpeg
# now the name of file is  middle.11.118.jpeg
# now the name of file is  middle.11.119.jpeg
# now the name of file is  middle.11.120.jpeg
# now the name of file is  middle.11.121.jpeg
# now the name of file is  middle.11.122.jpeg
# now the name of file is  middle.11.123.jpeg
# now the name of file is  middle.11.124.jpeg
# now the name of file is  middle.11.125.jpeg
# now the name of file is  middle.11.126.jpeg
# now the name of file is  middle.11.127.jpeg
# now the name of file is  middle.11.128.jpeg
# now the name of file is  middle.11.129.jpeg
# now the name of file is  middle.11.130.jpeg
# now the name of file is  middle.11.131.jpeg
# now the name of file is  middle.11.132.jpeg
# now the name of file is  middle.11.133.jpeg
# now the name of file is  middle.11.134.jpeg
# now the name of file is  middle.11.135.jpeg
# now the name of file is  middle.11.136.jpeg
# now the name of file is  middle.11.137.jpeg
# now the name of file is  middle.11.138.jpeg
# now the name of file is  middle.11.139.jpeg
# now the name of file is  middle.11.140.jpeg
# now the name of file is  middle.11.141.jpeg
# now the name of file is  middle.11.142.jpeg
# now the name of file is  middle.11.143.jpeg
# now the name of file is  middle.11.144.jpeg
# now the name of file is  middle.11.145.jpeg
# now the name of file is  middle.11.146.jpeg
# now the name of file is  middle.11.147.jpeg
# now the name of file is  middle.11.148.jpeg
# now the name of file is  middle.11.149.jpeg
# now the name of file is  middle.11.150.jpeg
# now the name of file is  middle.11.151.jpeg
# ***now the execution have done this time in the local host***
# now is the number  12  :
# now the name of file is  middle.12.1.jpeg
# now the name of file is  middle.12.2.jpeg
# now the name of file is  middle.12.3.jpeg
# now the name of file is  middle.12.4.jpeg
# now the name of file is  middle.12.5.jpeg
# now the name of file is  middle.12.6.jpeg
# now the name of file is  middle.12.7.jpeg
# now the name of file is  middle.12.8.jpeg
# now the name of file is  middle.12.9.jpeg
# now the name of file is  middle.12.10.jpeg
# now the name of file is  middle.12.11.jpeg
# now the name of file is  middle.12.12.jpeg
# now the name of file is  middle.12.13.jpeg
# now the name of file is  middle.12.14.jpeg
# now the name of file is  middle.12.15.jpeg
# now the name of file is  middle.12.16.jpeg
# now the name of file is  middle.12.17.jpeg
# now the name of file is  middle.12.18.jpeg
# now the name of file is  middle.12.19.jpeg
# now the name of file is  middle.12.20.jpeg
# now the name of file is  middle.12.21.jpeg
# now the name of file is  middle.12.22.jpeg
# now the name of file is  middle.12.23.jpeg
# now the name of file is  middle.12.24.jpeg
# now the name of file is  middle.12.25.jpeg
# now the name of file is  middle.12.26.jpeg
# now the name of file is  middle.12.27.jpeg
# now the name of file is  middle.12.28.jpeg
# now the name of file is  middle.12.29.jpeg
# now the name of file is  middle.12.30.jpeg
# now the name of file is  middle.12.31.jpeg
# now the name of file is  middle.12.32.jpeg
# now the name of file is  middle.12.33.jpeg
# now the name of file is  middle.12.34.jpeg
# now the name of file is  middle.12.35.jpeg
# ***now the execution have done this time in the local host***
# now is the number  13  :
# now the name of file is  middle.13.1.jpeg
# now the name of file is  middle.13.2.jpeg
# now the name of file is  middle.13.3.jpeg
# now the name of file is  middle.13.4.jpeg
# now the name of file is  middle.13.5.jpeg
# now the name of file is  middle.13.6.jpeg
# now the name of file is  middle.13.7.jpeg
# now the name of file is  middle.13.8.jpeg
# now the name of file is  middle.13.9.jpeg
# now the name of file is  middle.13.10.jpeg
# now the name of file is  middle.13.11.jpeg
# now the name of file is  middle.13.12.jpeg
# now the name of file is  middle.13.13.jpeg
# now the name of file is  middle.13.14.jpeg
# now the name of file is  middle.13.15.jpeg
# now the name of file is  middle.13.16.jpeg
# now the name of file is  middle.13.17.jpeg
# now the name of file is  middle.13.18.jpeg
# now the name of file is  middle.13.19.jpeg
# now the name of file is  middle.13.20.jpeg
# now the name of file is  middle.13.21.jpeg
# now the name of file is  middle.13.22.jpeg
# now the name of file is  middle.13.23.jpeg
# now the name of file is  middle.13.24.jpeg
# now the name of file is  middle.13.25.jpeg
# now the name of file is  middle.13.26.jpeg
# now the name of file is  middle.13.27.jpeg
# now the name of file is  middle.13.28.jpeg
# now the name of file is  middle.13.29.jpeg
# now the name of file is  middle.13.30.jpeg
# now the name of file is  middle.13.31.jpeg
# now the name of file is  middle.13.32.jpeg
# now the name of file is  middle.13.33.jpeg
# now the name of file is  middle.13.34.jpeg
# now the name of file is  middle.13.35.jpeg
# now the name of file is  middle.13.36.jpeg
# now the name of file is  middle.13.37.jpeg
# now the name of file is  middle.13.38.jpeg
# now the name of file is  middle.13.39.jpeg
# now the name of file is  middle.13.40.jpeg
# now the name of file is  middle.13.41.jpeg
# now the name of file is  middle.13.42.jpeg
# now the name of file is  middle.13.43.jpeg
# now the name of file is  middle.13.44.jpeg
# now the name of file is  middle.13.45.jpeg
# now the name of file is  middle.13.46.jpeg
# now the name of file is  middle.13.47.jpeg
# now the name of file is  middle.13.48.jpeg
# now the name of file is  middle.13.49.jpeg
# now the name of file is  middle.13.50.jpeg
# now the name of file is  middle.13.51.jpeg
# now the name of file is  middle.13.52.jpeg
# now the name of file is  middle.13.53.jpeg
# now the name of file is  middle.13.54.jpeg
# now the name of file is  middle.13.55.jpeg
# now the name of file is  middle.13.56.jpeg
# now the name of file is  middle.13.57.jpeg
# now the name of file is  middle.13.58.jpeg
# now the name of file is  middle.13.59.jpeg
# now the name of file is  middle.13.60.jpeg
# now the name of file is  middle.13.61.jpeg
# now the name of file is  middle.13.62.jpeg
# now the name of file is  middle.13.63.jpeg
# now the name of file is  middle.13.64.jpeg
# now the name of file is  middle.13.65.jpeg
# now the name of file is  middle.13.66.jpeg
# now the name of file is  middle.13.67.jpeg
# now the name of file is  middle.13.68.jpeg
# now the name of file is  middle.13.69.jpeg
# now the name of file is  middle.13.70.jpeg
# now the name of file is  middle.13.71.jpeg
# now the name of file is  middle.13.72.jpeg
# now the name of file is  middle.13.73.jpeg
# now the name of file is  middle.13.74.jpeg
# now the name of file is  middle.13.75.jpeg
# now the name of file is  middle.13.76.jpeg
# now the name of file is  middle.13.77.jpeg
# now the name of file is  middle.13.78.jpeg
# now the name of file is  middle.13.79.jpeg
# now the name of file is  middle.13.80.jpeg
# now the name of file is  middle.13.81.jpeg
# now the name of file is  middle.13.82.jpeg
# now the name of file is  middle.13.83.jpeg
# now the name of file is  middle.13.84.jpeg
# now the name of file is  middle.13.85.jpeg
# now the name of file is  middle.13.86.jpeg
# now the name of file is  middle.13.87.jpeg
# now the name of file is  middle.13.88.jpeg
# now the name of file is  middle.13.89.jpeg
# now the name of file is  middle.13.90.jpeg
# now the name of file is  middle.13.91.jpeg
# now the name of file is  middle.13.92.jpeg
# now the name of file is  middle.13.93.jpeg
# now the name of file is  middle.13.94.jpeg
# now the name of file is  middle.13.95.jpeg
# now the name of file is  middle.13.96.jpeg
# now the name of file is  middle.13.97.jpeg
# now the name of file is  middle.13.98.jpeg
# now the name of file is  middle.13.99.jpeg
# now the name of file is  middle.13.100.jpeg
# now the name of file is  middle.13.101.jpeg
# now the name of file is  middle.13.102.jpeg
# now the name of file is  middle.13.103.jpeg
# now the name of file is  middle.13.104.jpeg
# ***now the execution have done this time in the local host***
# now is the number  14  :
# now the name of file is  middle.14.1.jpeg
# now the name of file is  middle.14.2.jpeg
# now the name of file is  middle.14.3.jpeg
# now the name of file is  middle.14.4.jpeg
# now the name of file is  middle.14.5.jpeg
# now the name of file is  middle.14.6.jpeg
# now the name of file is  middle.14.7.jpeg
# now the name of file is  middle.14.8.jpeg
# now the name of file is  middle.14.9.jpeg
# now the name of file is  middle.14.10.jpeg
# now the name of file is  middle.14.11.jpeg
# now the name of file is  middle.14.12.jpeg
# now the name of file is  middle.14.13.jpeg
# now the name of file is  middle.14.14.jpeg
# now the name of file is  middle.14.15.jpeg
# now the name of file is  middle.14.16.jpeg
# now the name of file is  middle.14.17.jpeg
# now the name of file is  middle.14.18.jpeg
# now the name of file is  middle.14.19.jpeg
# now the name of file is  middle.14.20.jpeg
# now the name of file is  middle.14.21.jpeg
# now the name of file is  middle.14.22.jpeg
# now the name of file is  middle.14.23.jpeg
# now the name of file is  middle.14.24.jpeg
# now the name of file is  middle.14.25.jpeg
# now the name of file is  middle.14.26.jpeg
# now the name of file is  middle.14.27.jpeg
# now the name of file is  middle.14.28.jpeg
# now the name of file is  middle.14.29.jpeg
# now the name of file is  middle.14.30.jpeg
# now the name of file is  middle.14.31.jpeg
# now the name of file is  middle.14.32.jpeg
# now the name of file is  middle.14.33.jpeg
# now the name of file is  middle.14.34.jpeg
# now the name of file is  middle.14.35.jpeg
# now the name of file is  middle.14.36.jpeg
# now the name of file is  middle.14.37.jpeg
# now the name of file is  middle.14.38.jpeg
# now the name of file is  middle.14.39.jpeg
# now the name of file is  middle.14.40.jpeg
# now the name of file is  middle.14.41.jpeg
# now the name of file is  middle.14.42.jpeg
# now the name of file is  middle.14.43.jpeg
# now the name of file is  middle.14.44.jpeg
# now the name of file is  middle.14.45.jpeg
# now the name of file is  middle.14.46.jpeg
# now the name of file is  middle.14.47.jpeg
# now the name of file is  middle.14.48.jpeg
# now the name of file is  middle.14.49.jpeg
# now the name of file is  middle.14.50.jpeg
# now the name of file is  middle.14.51.jpeg
# now the name of file is  middle.14.52.jpeg
# now the name of file is  middle.14.53.jpeg
# now the name of file is  middle.14.54.jpeg
# now the name of file is  middle.14.55.jpeg
# now the name of file is  middle.14.56.jpeg
# now the name of file is  middle.14.57.jpeg
# now the name of file is  middle.14.58.jpeg
# now the name of file is  middle.14.59.jpeg
# now the name of file is  middle.14.60.jpeg
# now the name of file is  middle.14.61.jpeg
# now the name of file is  middle.14.62.jpeg
# now the name of file is  middle.14.63.jpeg
# now the name of file is  middle.14.64.jpeg
# now the name of file is  middle.14.65.jpeg
# now the name of file is  middle.14.66.jpeg
# now the name of file is  middle.14.67.jpeg
# ***now the execution have done this time in the local host***
# now is the number  15  :
# now the name of file is  middle.15.1.jpeg
# now the name of file is  middle.15.2.jpeg
# now the name of file is  middle.15.3.jpeg
# now the name of file is  middle.15.4.jpeg
# now the name of file is  middle.15.5.jpeg
# now the name of file is  middle.15.6.jpeg
# now the name of file is  middle.15.7.jpeg
# ***now the execution have done this time in the local host***
# now is the number  16  :
# now the name of file is  middle.16.1.jpeg
# now the name of file is  middle.16.2.jpeg
# now the name of file is  middle.16.3.jpeg
# now the name of file is  middle.16.4.jpeg
# now the name of file is  middle.16.5.jpeg
# now the name of file is  middle.16.6.jpeg
# now the name of file is  middle.16.7.jpeg
# now the name of file is  middle.16.8.jpeg
# now the name of file is  middle.16.9.jpeg
# now the name of file is  middle.16.10.jpeg
# now the name of file is  middle.16.11.jpeg
# now the name of file is  middle.16.12.jpeg
# now the name of file is  middle.16.13.jpeg
# now the name of file is  middle.16.14.jpeg
# now the name of file is  middle.16.15.jpeg
# now the name of file is  middle.16.16.jpeg
# now the name of file is  middle.16.17.jpeg
# now the name of file is  middle.16.18.jpeg
# now the name of file is  middle.16.19.jpeg
# now the name of file is  middle.16.20.jpeg
# now the name of file is  middle.16.21.jpeg
# now the name of file is  middle.16.22.jpeg
# now the name of file is  middle.16.23.jpeg
# now the name of file is  middle.16.24.jpeg
# now the name of file is  middle.16.25.jpeg
# now the name of file is  middle.16.26.jpeg
# now the name of file is  middle.16.27.jpeg
# ***now the execution have done this time in the local host***
# now is the number  17  :
# now the name of file is  middle.17.1.jpeg
# now the name of file is  middle.17.2.jpeg
# now the name of file is  middle.17.3.jpeg
# now the name of file is  middle.17.4.jpeg
# now the name of file is  middle.17.5.jpeg
# now the name of file is  middle.17.6.jpeg
# now the name of file is  middle.17.7.jpeg
# now the name of file is  middle.17.8.jpeg
# now the name of file is  middle.17.9.jpeg
# now the name of file is  middle.17.10.jpeg
# now the name of file is  middle.17.11.jpeg
# now the name of file is  middle.17.12.jpeg
# now the name of file is  middle.17.13.jpeg
# ***now the execution have done this time in the local host***
# now is the number  18  :
# now the name of file is  middle.18.1.jpeg
# now the name of file is  middle.18.2.jpeg
# now the name of file is  middle.18.3.jpeg
# now the name of file is  middle.18.4.jpeg
# now the name of file is  middle.18.5.jpeg
# now the name of file is  middle.18.6.jpeg
# now the name of file is  middle.18.7.jpeg
# now the name of file is  middle.18.8.jpeg
# now the name of file is  middle.18.9.jpeg
# now the name of file is  middle.18.10.jpeg
# now the name of file is  middle.18.11.jpeg
# now the name of file is  middle.18.12.jpeg
# now the name of file is  middle.18.13.jpeg
# now the name of file is  middle.18.14.jpeg
# now the name of file is  middle.18.15.jpeg
# now the name of file is  middle.18.16.jpeg
# now the name of file is  middle.18.17.jpeg
# now the name of file is  middle.18.18.jpeg
# now the name of file is  middle.18.19.jpeg
# now the name of file is  middle.18.20.jpeg
# now the name of file is  middle.18.21.jpeg
# now the name of file is  middle.18.22.jpeg
# now the name of file is  middle.18.23.jpeg
# now the name of file is  middle.18.24.jpeg
# now the name of file is  middle.18.25.jpeg
# now the name of file is  middle.18.26.jpeg
# now the name of file is  middle.18.27.jpeg
# now the name of file is  middle.18.28.jpeg
# now the name of file is  middle.18.29.jpeg
# now the name of file is  middle.18.30.jpeg
# now the name of file is  middle.18.31.jpeg
# now the name of file is  middle.18.32.jpeg
# now the name of file is  middle.18.33.jpeg
# now the name of file is  middle.18.34.jpeg
# now the name of file is  middle.18.35.jpeg
# now the name of file is  middle.18.36.jpeg
# now the name of file is  middle.18.37.jpeg
# now the name of file is  middle.18.38.jpeg
# now the name of file is  middle.18.39.jpeg
# now the name of file is  middle.18.40.jpeg
# now the name of file is  middle.18.41.jpeg
# now the name of file is  middle.18.42.jpeg
# now the name of file is  middle.18.43.jpeg
# now the name of file is  middle.18.44.jpeg
# now the name of file is  middle.18.45.jpeg
# now the name of file is  middle.18.46.jpeg
# now the name of file is  middle.18.47.jpeg
# now the name of file is  middle.18.48.jpeg
# now the name of file is  middle.18.49.jpeg
# now the name of file is  middle.18.50.jpeg
# now the name of file is  middle.18.51.jpeg
# now the name of file is  middle.18.52.jpeg
# now the name of file is  middle.18.53.jpeg
# now the name of file is  middle.18.54.jpeg
# now the name of file is  middle.18.55.jpeg
# now the name of file is  middle.18.56.jpeg
# now the name of file is  middle.18.57.jpeg
# now the name of file is  middle.18.58.jpeg
# now the name of file is  middle.18.59.jpeg
# now the name of file is  middle.18.60.jpeg
# now the name of file is  middle.18.61.jpeg
# now the name of file is  middle.18.62.jpeg
# now the name of file is  middle.18.63.jpeg
# now the name of file is  middle.18.64.jpeg
# now the name of file is  middle.18.65.jpeg
# now the name of file is  middle.18.66.jpeg
# now the name of file is  middle.18.67.jpeg
# now the name of file is  middle.18.68.jpeg
# now the name of file is  middle.18.69.jpeg
# now the name of file is  middle.18.70.jpeg
# now the name of file is  middle.18.71.jpeg
# now the name of file is  middle.18.72.jpeg
# now the name of file is  middle.18.73.jpeg
# now the name of file is  middle.18.74.jpeg
# now the name of file is  middle.18.75.jpeg
# now the name of file is  middle.18.76.jpeg
# now the name of file is  middle.18.77.jpeg
# now the name of file is  middle.18.78.jpeg
# now the name of file is  middle.18.79.jpeg
# now the name of file is  middle.18.80.jpeg
# now the name of file is  middle.18.81.jpeg
# now the name of file is  middle.18.82.jpeg
# now the name of file is  middle.18.83.jpeg
# now the name of file is  middle.18.84.jpeg
# now the name of file is  middle.18.85.jpeg
# now the name of file is  middle.18.86.jpeg
# now the name of file is  middle.18.87.jpeg
# now the name of file is  middle.18.88.jpeg
# now the name of file is  middle.18.89.jpeg
# now the name of file is  middle.18.90.jpeg
# now the name of file is  middle.18.91.jpeg
# now the name of file is  middle.18.92.jpeg
# now the name of file is  middle.18.93.jpeg
# now the name of file is  middle.18.94.jpeg
# now the name of file is  middle.18.95.jpeg
# now the name of file is  middle.18.96.jpeg
# now the name of file is  middle.18.97.jpeg
# now the name of file is  middle.18.98.jpeg
# now the name of file is  middle.18.99.jpeg
# now the name of file is  middle.18.100.jpeg
# now the name of file is  middle.18.101.jpeg
# now the name of file is  middle.18.102.jpeg
# now the name of file is  middle.18.103.jpeg
# now the name of file is  middle.18.104.jpeg
# now the name of file is  middle.18.105.jpeg
# now the name of file is  middle.18.106.jpeg
# now the name of file is  middle.18.107.jpeg
# now the name of file is  middle.18.108.jpeg
# now the name of file is  middle.18.109.jpeg
# now the name of file is  middle.18.110.jpeg
# now the name of file is  middle.18.111.jpeg
# now the name of file is  middle.18.112.jpeg
# now the name of file is  middle.18.113.jpeg
# now the name of file is  middle.18.114.jpeg
# now the name of file is  middle.18.115.jpeg
# now the name of file is  middle.18.116.jpeg
# now the name of file is  middle.18.117.jpeg
# now the name of file is  middle.18.118.jpeg
# now the name of file is  middle.18.119.jpeg
# now the name of file is  middle.18.120.jpeg
# now the name of file is  middle.18.121.jpeg
# now the name of file is  middle.18.122.jpeg
# now the name of file is  middle.18.123.jpeg
# now the name of file is  middle.18.124.jpeg
# now the name of file is  middle.18.125.jpeg
# now the name of file is  middle.18.126.jpeg
# now the name of file is  middle.18.127.jpeg
# now the name of file is  middle.18.128.jpeg
# now the name of file is  middle.18.129.jpeg
# now the name of file is  middle.18.130.jpeg
# now the name of file is  middle.18.131.jpeg
# now the name of file is  middle.18.132.jpeg
# now the name of file is  middle.18.133.jpeg
# now the name of file is  middle.18.134.jpeg
# now the name of file is  middle.18.135.jpeg
# now the name of file is  middle.18.136.jpeg
# now the name of file is  middle.18.137.jpeg
# now the name of file is  middle.18.138.jpeg
# now the name of file is  middle.18.139.jpeg
# now the name of file is  middle.18.140.jpeg
# now the name of file is  middle.18.141.jpeg
# now the name of file is  middle.18.142.jpeg
# now the name of file is  middle.18.143.jpeg
# now the name of file is  middle.18.144.jpeg
# now the name of file is  middle.18.145.jpeg
# now the name of file is  middle.18.146.jpeg
# now the name of file is  middle.18.147.jpeg
# now the name of file is  middle.18.148.jpeg
# now the name of file is  middle.18.149.jpeg
# now the name of file is  middle.18.150.jpeg
# now the name of file is  middle.18.151.jpeg
# ***now the execution have done this time in the local host***
# now is the number  19  :
# now the name of file is  middle.19.1.jpeg
# now the name of file is  middle.19.2.jpeg
# now the name of file is  middle.19.3.jpeg
# now the name of file is  middle.19.4.jpeg
# now the name of file is  middle.19.5.jpeg
# now the name of file is  middle.19.6.jpeg
# now the name of file is  middle.19.7.jpeg
# ***now the execution have done this time in the local host***
# now is the number  20  :
# now the name of file is  middle.20.1.jpeg
# now the name of file is  middle.20.2.jpeg
# now the name of file is  middle.20.3.jpeg
# now the name of file is  middle.20.4.jpeg
# now the name of file is  middle.20.5.jpeg
# now the name of file is  middle.20.6.jpeg
# now the name of file is  middle.20.7.jpeg
# now the name of file is  middle.20.8.jpeg
# now the name of file is  middle.20.9.jpeg
# now the name of file is  middle.20.10.jpeg
# now the name of file is  middle.20.11.jpeg
# ...
# now the name of file is  middle.93.216.jpeg
# now the name of file is  middle.93.217.jpeg
# now the name of file is  middle.93.218.jpeg
# now the name of file is  middle.93.219.jpeg
# now the name of file is  middle.93.220.jpeg
# now the name of file is  middle.93.221.jpeg
# now the name of file is  middle.93.222.jpeg
# now the name of file is  middle.93.223.jpeg
# now the name of file is  middle.93.224.jpeg
# now the name of file is  middle.93.225.jpeg
# now the name of file is  middle.93.226.jpeg
# ***now the execution have done this time in the local host***
# now is the number  94  :
# now the name of file is  middle.94.1.jpeg
# now the name of file is  middle.94.2.jpeg
# now the name of file is  middle.94.3.jpeg
# now the name of file is  middle.94.4.jpeg
# now the name of file is  middle.94.5.jpeg
# now the name of file is  middle.94.6.jpeg
# ***now the execution have done this time in the local host***
# now is the number  95  :
# now the name of file is  middle.95.1.jpeg
# now the name of file is  middle.95.2.jpeg
# now the name of file is  middle.95.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  96  :
# now the name of file is  middle.96.1.jpeg
# now the name of file is  middle.96.2.jpeg
# now the name of file is  middle.96.3.jpeg
# now the name of file is  middle.96.4.jpeg
# now the name of file is  middle.96.5.jpeg
# now the name of file is  middle.96.6.jpeg
# now the name of file is  middle.96.7.jpeg
# now the name of file is  middle.96.8.jpeg
# now the name of file is  middle.96.9.jpeg
# now the name of file is  middle.96.10.jpeg
# now the name of file is  middle.96.11.jpeg
# now the name of file is  middle.96.12.jpeg
# now the name of file is  middle.96.13.jpeg
# now the name of file is  middle.96.14.jpeg
# now the name of file is  middle.96.15.jpeg
# now the name of file is  middle.96.16.jpeg
# now the name of file is  middle.96.17.jpeg
# now the name of file is  middle.96.18.jpeg
# now the name of file is  middle.96.19.jpeg
# now the name of file is  middle.96.20.jpeg
# now the name of file is  middle.96.21.jpeg
# now the name of file is  middle.96.22.jpeg
# now the name of file is  middle.96.23.jpeg
# now the name of file is  middle.96.24.jpeg
# now the name of file is  middle.96.25.jpeg
# now the name of file is  middle.96.26.jpeg
# now the name of file is  middle.96.27.jpeg
# now the name of file is  middle.96.28.jpeg
# now the name of file is  middle.96.29.jpeg
# now the name of file is  middle.96.30.jpeg
# now the name of file is  middle.96.31.jpeg
# now the name of file is  middle.96.32.jpeg
# now the name of file is  middle.96.33.jpeg
# now the name of file is  middle.96.34.jpeg
# now the name of file is  middle.96.35.jpeg
# now the name of file is  middle.96.36.jpeg
# now the name of file is  middle.96.37.jpeg
# now the name of file is  middle.96.38.jpeg
# now the name of file is  middle.96.39.jpeg
# now the name of file is  middle.96.40.jpeg
# now the name of file is  middle.96.41.jpeg
# now the name of file is  middle.96.42.jpeg
# now the name of file is  middle.96.43.jpeg
# now the name of file is  middle.96.44.jpeg
# now the name of file is  middle.96.45.jpeg
# now the name of file is  middle.96.46.jpeg
# now the name of file is  middle.96.47.jpeg
# now the name of file is  middle.96.48.jpeg
# now the name of file is  middle.96.49.jpeg
# now the name of file is  middle.96.50.jpeg
# now the name of file is  middle.96.51.jpeg
# now the name of file is  middle.96.52.jpeg
# now the name of file is  middle.96.53.jpeg
# now the name of file is  middle.96.54.jpeg
# now the name of file is  middle.96.55.jpeg
# now the name of file is  middle.96.56.jpeg
# now the name of file is  middle.96.57.jpeg
# now the name of file is  middle.96.58.jpeg
# now the name of file is  middle.96.59.jpeg
# now the name of file is  middle.96.60.jpeg
# now the name of file is  middle.96.61.jpeg
# now the name of file is  middle.96.62.jpeg
# now the name of file is  middle.96.63.jpeg
# now the name of file is  middle.96.64.jpeg
# now the name of file is  middle.96.65.jpeg
# now the name of file is  middle.96.66.jpeg
# now the name of file is  middle.96.67.jpeg
# now the name of file is  middle.96.68.jpeg
# now the name of file is  middle.96.69.jpeg
# now the name of file is  middle.96.70.jpeg
# now the name of file is  middle.96.71.jpeg
# now the name of file is  middle.96.72.jpeg
# now the name of file is  middle.96.73.jpeg
# now the name of file is  middle.96.74.jpeg
# now the name of file is  middle.96.75.jpeg
# now the name of file is  middle.96.76.jpeg
# now the name of file is  middle.96.77.jpeg
# now the name of file is  middle.96.78.jpeg
# now the name of file is  middle.96.79.jpeg
# now the name of file is  middle.96.80.jpeg
# now the name of file is  middle.96.81.jpeg
# now the name of file is  middle.96.82.jpeg
# now the name of file is  middle.96.83.jpeg
# now the name of file is  middle.96.84.jpeg
# now the name of file is  middle.96.85.jpeg
# now the name of file is  middle.96.86.jpeg
# now the name of file is  middle.96.87.jpeg
# now the name of file is  middle.96.88.jpeg
# now the name of file is  middle.96.89.jpeg
# now the name of file is  middle.96.90.jpeg
# now the name of file is  middle.96.91.jpeg
# now the name of file is  middle.96.92.jpeg
# now the name of file is  middle.96.93.jpeg
# now the name of file is  middle.96.94.jpeg
# now the name of file is  middle.96.95.jpeg
# now the name of file is  middle.96.96.jpeg
# now the name of file is  middle.96.97.jpeg
# now the name of file is  middle.96.98.jpeg
# now the name of file is  middle.96.99.jpeg
# now the name of file is  middle.96.100.jpeg
# now the name of file is  middle.96.101.jpeg
# now the name of file is  middle.96.102.jpeg
# now the name of file is  middle.96.103.jpeg
# now the name of file is  middle.96.104.jpeg
# now the name of file is  middle.96.105.jpeg
# now the name of file is  middle.96.106.jpeg
# now the name of file is  middle.96.107.jpeg
# now the name of file is  middle.96.108.jpeg
# now the name of file is  middle.96.109.jpeg
# now the name of file is  middle.96.110.jpeg
# now the name of file is  middle.96.111.jpeg
# now the name of file is  middle.96.112.jpeg
# now the name of file is  middle.96.113.jpeg
# now the name of file is  middle.96.114.jpeg
# now the name of file is  middle.96.115.jpeg
# now the name of file is  middle.96.116.jpeg
# now the name of file is  middle.96.117.jpeg
# now the name of file is  middle.96.118.jpeg
# now the name of file is  middle.96.119.jpeg
# now the name of file is  middle.96.120.jpeg
# now the name of file is  middle.96.121.jpeg
# now the name of file is  middle.96.122.jpeg
# now the name of file is  middle.96.123.jpeg
# now the name of file is  middle.96.124.jpeg
# now the name of file is  middle.96.125.jpeg
# now the name of file is  middle.96.126.jpeg
# now the name of file is  middle.96.127.jpeg
# now the name of file is  middle.96.128.jpeg
# now the name of file is  middle.96.129.jpeg
# now the name of file is  middle.96.130.jpeg
# now the name of file is  middle.96.131.jpeg
# now the name of file is  middle.96.132.jpeg
# now the name of file is  middle.96.133.jpeg
# now the name of file is  middle.96.134.jpeg
# now the name of file is  middle.96.135.jpeg
# now the name of file is  middle.96.136.jpeg
# now the name of file is  middle.96.137.jpeg
# now the name of file is  middle.96.138.jpeg
# now the name of file is  middle.96.139.jpeg
# now the name of file is  middle.96.140.jpeg
# now the name of file is  middle.96.141.jpeg
# now the name of file is  middle.96.142.jpeg
# now the name of file is  middle.96.143.jpeg
# now the name of file is  middle.96.144.jpeg
# now the name of file is  middle.96.145.jpeg
# now the name of file is  middle.96.146.jpeg
# now the name of file is  middle.96.147.jpeg
# now the name of file is  middle.96.148.jpeg
# now the name of file is  middle.96.149.jpeg
# now the name of file is  middle.96.150.jpeg
# now the name of file is  middle.96.151.jpeg
# now the name of file is  middle.96.152.jpeg
# now the name of file is  middle.96.153.jpeg
# now the name of file is  middle.96.154.jpeg
# now the name of file is  middle.96.155.jpeg
# now the name of file is  middle.96.156.jpeg
# now the name of file is  middle.96.157.jpeg
# now the name of file is  middle.96.158.jpeg
# now the name of file is  middle.96.159.jpeg
# now the name of file is  middle.96.160.jpeg
# now the name of file is  middle.96.161.jpeg
# now the name of file is  middle.96.162.jpeg
# now the name of file is  middle.96.163.jpeg
# now the name of file is  middle.96.164.jpeg
# now the name of file is  middle.96.165.jpeg
# now the name of file is  middle.96.166.jpeg
# now the name of file is  middle.96.167.jpeg
# now the name of file is  middle.96.168.jpeg
# now the name of file is  middle.96.169.jpeg
# now the name of file is  middle.96.170.jpeg
# now the name of file is  middle.96.171.jpeg
# now the name of file is  middle.96.172.jpeg
# now the name of file is  middle.96.173.jpeg
# now the name of file is  middle.96.174.jpeg
# now the name of file is  middle.96.175.jpeg
# now the name of file is  middle.96.176.jpeg
# now the name of file is  middle.96.177.jpeg
# now the name of file is  middle.96.178.jpeg
# now the name of file is  middle.96.179.jpeg
# now the name of file is  middle.96.180.jpeg
# now the name of file is  middle.96.181.jpeg
# now the name of file is  middle.96.182.jpeg
# now the name of file is  middle.96.183.jpeg
# now the name of file is  middle.96.184.jpeg
# now the name of file is  middle.96.185.jpeg
# now the name of file is  middle.96.186.jpeg
# now the name of file is  middle.96.187.jpeg
# now the name of file is  middle.96.188.jpeg
# now the name of file is  middle.96.189.jpeg
# ***now the execution have done this time in the local host***
# now is the number  97  :
# now the name of file is  middle.97.1.jpeg
# now the name of file is  middle.97.2.jpeg
# now the name of file is  middle.97.3.jpeg
# now the name of file is  middle.97.4.jpeg
# now the name of file is  middle.97.5.jpeg
# now the name of file is  middle.97.6.jpeg
# now the name of file is  middle.97.7.jpeg
# now the name of file is  middle.97.8.jpeg
# now the name of file is  middle.97.9.jpeg
# now the name of file is  middle.97.10.jpeg
# now the name of file is  middle.97.11.jpeg
# now the name of file is  middle.97.12.jpeg
# now the name of file is  middle.97.13.jpeg
# now the name of file is  middle.97.14.jpeg
# now the name of file is  middle.97.15.jpeg
# now the name of file is  middle.97.16.jpeg
# now the name of file is  middle.97.17.jpeg
# now the name of file is  middle.97.18.jpeg
# now the name of file is  middle.97.19.jpeg
# now the name of file is  middle.97.20.jpeg
# now the name of file is  middle.97.21.jpeg
# now the name of file is  middle.97.22.jpeg
# now the name of file is  middle.97.23.jpeg
# now the name of file is  middle.97.24.jpeg
# now the name of file is  middle.97.25.jpeg
# now the name of file is  middle.97.26.jpeg
# now the name of file is  middle.97.27.jpeg
# now the name of file is  middle.97.28.jpeg
# now the name of file is  middle.97.29.jpeg
# now the name of file is  middle.97.30.jpeg
# now the name of file is  middle.97.31.jpeg
# now the name of file is  middle.97.32.jpeg
# now the name of file is  middle.97.33.jpeg
# now the name of file is  middle.97.34.jpeg
# now the name of file is  middle.97.35.jpeg
# now the name of file is  middle.97.36.jpeg
# now the name of file is  middle.97.37.jpeg
# now the name of file is  middle.97.38.jpeg
# now the name of file is  middle.97.39.jpeg
# now the name of file is  middle.97.40.jpeg
# now the name of file is  middle.97.41.jpeg
# now the name of file is  middle.97.42.jpeg
# now the name of file is  middle.97.43.jpeg
# now the name of file is  middle.97.44.jpeg
# now the name of file is  middle.97.45.jpeg
# now the name of file is  middle.97.46.jpeg
# now the name of file is  middle.97.47.jpeg
# now the name of file is  middle.97.48.jpeg
# now the name of file is  middle.97.49.jpeg
# now the name of file is  middle.97.50.jpeg
# now the name of file is  middle.97.51.jpeg
# now the name of file is  middle.97.52.jpeg
# now the name of file is  middle.97.53.jpeg
# now the name of file is  middle.97.54.jpeg
# now the name of file is  middle.97.55.jpeg
# now the name of file is  middle.97.56.jpeg
# now the name of file is  middle.97.57.jpeg
# now the name of file is  middle.97.58.jpeg
# now the name of file is  middle.97.59.jpeg
# now the name of file is  middle.97.60.jpeg
# now the name of file is  middle.97.61.jpeg
# now the name of file is  middle.97.62.jpeg
# now the name of file is  middle.97.63.jpeg
# now the name of file is  middle.97.64.jpeg
# now the name of file is  middle.97.65.jpeg
# now the name of file is  middle.97.66.jpeg
# now the name of file is  middle.97.67.jpeg
# now the name of file is  middle.97.68.jpeg
# now the name of file is  middle.97.69.jpeg
# now the name of file is  middle.97.70.jpeg
# now the name of file is  middle.97.71.jpeg
# now the name of file is  middle.97.72.jpeg
# now the name of file is  middle.97.73.jpeg
# now the name of file is  middle.97.74.jpeg
# now the name of file is  middle.97.75.jpeg
# now the name of file is  middle.97.76.jpeg
# now the name of file is  middle.97.77.jpeg
# now the name of file is  middle.97.78.jpeg
# now the name of file is  middle.97.79.jpeg
# now the name of file is  middle.97.80.jpeg
# now the name of file is  middle.97.81.jpeg
# now the name of file is  middle.97.82.jpeg
# now the name of file is  middle.97.83.jpeg
# now the name of file is  middle.97.84.jpeg
# now the name of file is  middle.97.85.jpeg
# now the name of file is  middle.97.86.jpeg
# now the name of file is  middle.97.87.jpeg
# now the name of file is  middle.97.88.jpeg
# now the name of file is  middle.97.89.jpeg
# now the name of file is  middle.97.90.jpeg
# now the name of file is  middle.97.91.jpeg
# now the name of file is  middle.97.92.jpeg
# now the name of file is  middle.97.93.jpeg
# now the name of file is  middle.97.94.jpeg
# now the name of file is  middle.97.95.jpeg
# now the name of file is  middle.97.96.jpeg
# now the name of file is  middle.97.97.jpeg
# now the name of file is  middle.97.98.jpeg
# now the name of file is  middle.97.99.jpeg
# now the name of file is  middle.97.100.jpeg
# now the name of file is  middle.97.101.jpeg
# now the name of file is  middle.97.102.jpeg
# now the name of file is  middle.97.103.jpeg
# now the name of file is  middle.97.104.jpeg
# now the name of file is  middle.97.105.jpeg
# now the name of file is  middle.97.106.jpeg
# now the name of file is  middle.97.107.jpeg
# now the name of file is  middle.97.108.jpeg
# now the name of file is  middle.97.109.jpeg
# now the name of file is  middle.97.110.jpeg
# now the name of file is  middle.97.111.jpeg
# now the name of file is  middle.97.112.jpeg
# now the name of file is  middle.97.113.jpeg
# now the name of file is  middle.97.114.jpeg
# now the name of file is  middle.97.115.jpeg
# now the name of file is  middle.97.116.jpeg
# now the name of file is  middle.97.117.jpeg
# now the name of file is  middle.97.118.jpeg
# ***now the execution have done this time in the local host***
# now is the number  98  :
# now the name of file is  middle.98.1.jpeg
# now the name of file is  middle.98.2.jpeg
# now the name of file is  middle.98.3.jpeg
# now the name of file is  middle.98.4.jpeg
# now the name of file is  middle.98.5.jpeg
# now the name of file is  middle.98.6.jpeg
# now the name of file is  middle.98.7.jpeg
# ***now the execution have done this time in the local host***
# now is the number  99  :
# now the name of file is  middle.99.1.jpeg
# now the name of file is  middle.99.2.jpeg
# now the name of file is  middle.99.3.jpeg
# now the name of file is  middle.99.4.jpeg
# now the name of file is  middle.99.5.jpeg
# now the name of file is  middle.99.6.jpeg
# now the name of file is  middle.99.7.jpeg
# now the name of file is  middle.99.8.jpeg
# now the name of file is  middle.99.9.jpeg
# now the name of file is  middle.99.10.jpeg
# now the name of file is  middle.99.11.jpeg
# now the name of file is  middle.99.12.jpeg
# now the name of file is  middle.99.13.jpeg
# now the name of file is  middle.99.14.jpeg
# now the name of file is  middle.99.15.jpeg
# now the name of file is  middle.99.16.jpeg
# now the name of file is  middle.99.17.jpeg
# now the name of file is  middle.99.18.jpeg
# now the name of file is  middle.99.19.jpeg
# now the name of file is  middle.99.20.jpeg
# now the name of file is  middle.99.21.jpeg
# now the name of file is  middle.99.22.jpeg
# ***now the execution have done this time in the local host***
# ---FINISHED---

# %%
import os
import requests

CONFIG_PATTERN = 'http://api.themoviedb.org/3/configuration?api_key=e7a9762dabfdc186e180a0791bb06e7c' 
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'

def _get_json(url):
    r = requests.get(url)
    return r.json()
    
def _download_images(urls, path='.'):
    """download all images in list 'urls' to 'path' """
    for nr, url in enumerate(urls):
        r = requests.get(url)
        filetype = r.headers['content-type'].split('/')[-1]
        filename = 'bottom.{0}.{1}'.format(nr+1, filetype)
        filepath = os.path.join(path, filename)
        with open(filepath,'wb') as w:
            w.write(r.content)
        print('now the name of file is ', filename)
        
def get_poster_urls(imdbid):
    """ return image urls of posters for IMDB id

        returns all poster images from 'themoviedb.org'. Uses the
        maximum available size. 

        Args:
            imdbid (str): IMDB id of the movie

        Returns:
            list: list of urls to the images
    """
    config = _get_json(CONFIG_PATTERN.format(key=KEY))
    IMG_PATTERN = 'http://api.themoviedb.org/3/movie/' + imdbid + '/images?api_key=e7a9762dabfdc186e180a0791bb06e7c'
    base_url = config['images']['base_url']
    sizes = config['images']['poster_sizes']

    """
        'sizes' should be sorted in ascending order, so
            max_size = sizes[-1]
        should get the largest size as well.        
    """
    def size_str_to_int(x):
        return float("inf") if x == 'original' else int(x[1:])
    max_size = max(sizes, key=size_str_to_int)

    posters = _get_json(IMG_PATTERN.format(key=KEY,imdbid=imdbid))['posters']
    poster_urls = []
    for poster in posters:
        rel_path = poster['file_path']
        url = "{0}{1}{2}".format(base_url, max_size, rel_path)
        poster_urls.append(url) 

    return poster_urls

def tmdb_posters(imdbid, count=None, outpath='.'): 
    urls = get_poster_urls(imdbid)
    if count is not None:
        urls = urls[:count]
    _download_images(urls, outpath)
    
def get_id_from_file(address):
    f= open(address, encoding = 'utf8')#讀所有詞
    s = f.read()
    #print(s)
    spilt_s = s.split("\n")
    return spilt_s

if __name__=="__main__":
    print('---STAR---')
    print('ready to get IMDb id from file...')
    list_of_movie_id = get_id_from_file('lowest_100_movies_id.txt')
    print('sucess')
    print('ready to download the movie poster in individual movie...')
    for i in range(0, len(list_of_movie_id)):
        print('now is the number ' , i , ' : ')
        tmdb_posters(list_of_movie_id[i])
        print('***now the execution have done this time in the local host***')
    print('---FINISHED---')
# Out:
# ---STAR---
# ready to get IMDb id from file...
# sucess
# ready to download the movie poster in individual movie...
# now is the number  0  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  1  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  2  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  3  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  4  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# ***now the execution have done this time in the local host***
# now is the number  5  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# ***now the execution have done this time in the local host***
# now is the number  6  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  7  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  8  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  9  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# ***now the execution have done this time in the local host***
# now is the number  10  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# ***now the execution have done this time in the local host***
# now is the number  11  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  12  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  13  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  14  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# ***now the execution have done this time in the local host***
# now is the number  15  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  16  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  17  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  18  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  19  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  20  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  21  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  22  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  23  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  24  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  25  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# ***now the execution have done this time in the local host***
# now is the number  26  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  27  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  28  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# ***now the execution have done this time in the local host***
# now is the number  29  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  30  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  31  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  32  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  33  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# now the name of file is  bottom.12.jpeg
# now the name of file is  bottom.13.jpeg
# now the name of file is  bottom.14.jpeg
# now the name of file is  bottom.15.jpeg
# now the name of file is  bottom.16.jpeg
# now the name of file is  bottom.17.jpeg
# now the name of file is  bottom.18.jpeg
# now the name of file is  bottom.19.jpeg
# now the name of file is  bottom.20.jpeg
# now the name of file is  bottom.21.jpeg
# now the name of file is  bottom.22.jpeg
# ***now the execution have done this time in the local host***
# now is the number  34  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  35  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  36  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# ***now the execution have done this time in the local host***
# now is the number  37  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  38  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  39  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# ***now the execution have done this time in the local host***
# now is the number  40  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  41  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  42  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  43  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  44  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  45  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  46  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# now the name of file is  bottom.12.jpeg
# now the name of file is  bottom.13.jpeg
# now the name of file is  bottom.14.jpeg
# now the name of file is  bottom.15.jpeg
# now the name of file is  bottom.16.jpeg
# now the name of file is  bottom.17.jpeg
# now the name of file is  bottom.18.jpeg
# now the name of file is  bottom.19.jpeg
# now the name of file is  bottom.20.jpeg
# now the name of file is  bottom.21.jpeg
# now the name of file is  bottom.22.jpeg
# now the name of file is  bottom.23.jpeg
# now the name of file is  bottom.24.jpeg
# now the name of file is  bottom.25.jpeg
# now the name of file is  bottom.26.jpeg
# now the name of file is  bottom.27.jpeg
# now the name of file is  bottom.28.jpeg
# ***now the execution have done this time in the local host***
# now is the number  47  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# now the name of file is  bottom.12.jpeg
# now the name of file is  bottom.13.jpeg
# now the name of file is  bottom.14.jpeg
# ***now the execution have done this time in the local host***
# now is the number  48  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  49  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  50  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  51  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  52  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  53  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# ***now the execution have done this time in the local host***
# now is the number  54  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  55  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  56  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  57  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  58  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# now the name of file is  bottom.12.jpeg
# now the name of file is  bottom.13.jpeg
# now the name of file is  bottom.14.jpeg
# now the name of file is  bottom.15.jpeg
# ***now the execution have done this time in the local host***
# now is the number  59  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# now the name of file is  bottom.12.jpeg
# now the name of file is  bottom.13.jpeg
# now the name of file is  bottom.14.jpeg
# ***now the execution have done this time in the local host***
# now is the number  60  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  61  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  62  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  63  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  64  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  65  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  66  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  67  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# ***now the execution have done this time in the local host***
# now is the number  68  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# ***now the execution have done this time in the local host***
# now is the number  69  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# ***now the execution have done this time in the local host***
# now is the number  70  :
# now the name of file is  bottom.1.jpeg
# ***now the execution have done this time in the local host***
# now is the number  71  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# ***now the execution have done this time in the local host***
# now is the number  72  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# ***now the execution have done this time in the local host***
# now is the number  73  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# now the name of file is  bottom.3.jpeg
# now the name of file is  bottom.4.jpeg
# now the name of file is  bottom.5.jpeg
# now the name of file is  bottom.6.jpeg
# now the name of file is  bottom.7.jpeg
# now the name of file is  bottom.8.jpeg
# now the name of file is  bottom.9.jpeg
# now the name of file is  bottom.10.jpeg
# now the name of file is  bottom.11.jpeg
# ***now the execution have done this time in the local host***
# now is the number  74  :
# now the name of file is  bottom.1.jpeg
# now the name of file is  bottom.2.jpeg
# ***now the execution have done this time in the local host***
# now is the number  75  :
# now the name of file is  bottom.1.jpeg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-33d7de5e55a9> in <module>()
#      76     for i in range(0, len(list_of_movie_id)):
#      77         print('now is the number ' , i , ' : ')
# ---> 78         tmdb_posters(list_of_movie_id[i])
#      79         print('***now the execution have done this time in the local host***')
#      80     print('---FINISHED---')
#
# <ipython-input-2-33d7de5e55a9> in tmdb_posters(imdbid, count, outpath)
#      59     if count is not None:
#      60         urls = urls[:count]
# ---> 61     _download_images(urls, outpath)
#      62
#      63 def get_id_from_file(address):
#
# <ipython-input-2-33d7de5e55a9> in _download_images(urls, path)
#      12     """download all images in list 'urls' to 'path' """
#      13     for nr, url in enumerate(urls):
# ---> 14         r = requests.get(url)
#      15         filetype = r.headers['content-type'].split('/')[-1]
#      16         filename = 'bottom.{0}.{1}'.format(nr+1, filetype)
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/py35/lib/python3.5/http/client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# ~/anaconda3/envs/py35/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/py35/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/py35/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/genre/movie/list?language=en-US&api_key=e7a9762dabfdc186e180a0791bb06e7c", payload)

res = conn.getresponse()
data_genre = res.read()
print(data_genre.decode("utf-8"))
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/person/popular?page=1&language=en-US&api_key=e7a9762dabfdc186e180a0791bb06e7c", payload)

res = conn.getresponse()
data_people = res.read()

print(data_people.decode("utf-8"))
# Out:
# {"page":1,"total_results":19554,"total_pages":978,"results":[{"popularity":63.677737,"id":819,"profile_path":"\/eIkFHNlfretLS1spAcIoihKUS62.jpg","name":"Edward Norton","known_for":[{"vote_average":8.3,"vote_count":11983,"id":550,"video":false,"media_type":"movie","title":"Fight Club","popularity":49.556511,"poster_path":"\/adw6Lq9FiC9zjYEpOqfq03ituwp.jpg","original_language":"en","original_title":"Fight Club","genre_ids":[18],"backdrop_path":"\/mMZRKb3NVo5ZeSPEIaNW9buLWQ0.jpg","adult":false,"overview":"A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground \"fight clubs\" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.","release_date":"1999-10-15"},{"vote_average":8,"vote_count":5861,"id":120467,"video":false,"media_type":"movie","title":"The Grand Budapest Hotel","popularity":32.827706,"poster_path":"\/nX5XotM9yprCKarRH4fzOq1VM1J.jpg","original_language":"en","original_title":"The Grand Budapest Hotel","genre_ids":[35,18],"backdrop_path":"\/5FPUoQtnNC0C0YZ7sUeTLq6eZqa.jpg","adult":false,"overview":"The Grand Budapest Hotel tells of a legendary concierge at a famous European hotel between the wars and his friendship with a young employee who becomes his trusted protégé. The story involves the theft and recovery of a priceless Renaissance painting, the battle for an enormous family fortune and the slow and then sudden upheavals that transformed Europe during the first half of the 20th century.","release_date":"2014-02-26"},{"vote_average":7.4,"vote_count":5619,"id":194662,"video":false,"media_type":"movie","title":"Birdman","popularity":57.235527,"poster_path":"\/rSZs93P0LLxqlVEbI001UKoeCQC.jpg","original_language":"en","original_title":"Birdman","genre_ids":[18,35],"backdrop_path":"\/pLMRBAKD9Nc9zjWRpqLXasNcf4F.jpg","adult":false,"overview":"A fading actor best known for his portrayal of a popular superhero attempts to mount a comeback by appearing in a Broadway play. As opening night approaches, his attempts to become more altruistic, rebuild his career, and reconnect with friends and family prove more difficult than expected.","release_date":"2014-08-27"}],"adult":false},{"popularity":40.508799,"id":1557698,"profile_path":"\/6CPr9fPCY9J3P1grFHqnWeUYvIL.jpg","name":"Dilraba Dilmurat","known_for":[{"original_name":"秦时丽人明月心","id":72487,"media_type":"tv","name":"The King's Woman","vote_count":19,"vote_average":3.85,"poster_path":"\/1HiqZJ0K2ZLjG9z4gzD1g4evr7H.jpg","first_air_date":"2017-08-14","popularity":9.612581,"genre_ids":[18],"original_language":"zh","backdrop_path":"\/yt4Iqhii6CcrQu96ogSvmZHtqLy.jpg","overview":"Gong Sun Li is the grand-daughter and disciple of military commander Gong Sun Yu. Jing Ke and Li have been in love with each other since they were children. While trying to protect Li during an attack, Jing Ke is poisoned. Li’s beauty has seized the interest of the Qin Emperor, Ying Zheng, and Li agrees to marry him in order to save Jing Ke.","origin_country":["CN"]},{"original_name":"三生三世十里桃花","id":69316,"media_type":"tv","name":"Three Lives Three Worlds, Ten Miles of Peach Blossoms","vote_count":10,"vote_average":5.8,"poster_path":"\/c7Pfx7dQiRsi1rU8N9s05gHnAkI.jpg","first_air_date":"2017-01-30","popularity":8.856681,"genre_ids":[18],"original_language":"zh","backdrop_path":"\/pgJkDvZtkyUXsdGC24EZrdDO2sQ.jpg","overview":"Three hundred years ago, Bai Qian stood on the Zhu Xian Terrace, turned around and jumped off without regret. Ye Hua stood by the bronze mirror to witness with his own eyes her death. Three hundred years later, in the East Sea Dragon Palace, the two meet unexpectedly. Another lifetime another world, after suffering betrayal Bai Qian no longer feels anything, yet she can't seem to comprehend Ye Hua's actions. Three lives three worlds, her and him, are they fated to love again?","origin_country":["CN"]},{"original_name":" ...

# %%
type(data_people)
# Out:
# bytes

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/discover/movie?api_key=e7a9762dabfdc186e180a0791bb06e7c&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=1&year=1994", payload)

res = conn.getresponse()
data_with_year = res.read()

print(data_with_year.decode("utf-8"))
# Out:
# {"page":1,"total_results":3406,"total_pages":171,"results":[{"vote_count":10894,"id":680,"video":false,"vote_average":8.3,"title":"Pulp Fiction","popularity":42.178956,"poster_path":"\/dM2w364MScsjFf8pfMbaWUcWrR.jpg","original_language":"en","original_title":"Pulp Fiction","genre_ids":[53,80],"backdrop_path":"\/mte63qJaVnoxkkXbHkdFujBnBgd.jpg","adult":false,"overview":"A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.","release_date":"1994-09-10"},{"vote_count":7007,"id":8587,"video":false,"vote_average":8.1,"title":"The Lion King","popularity":41.521462,"poster_path":"\/bKPtXn9n4M4s8vvZrbw40mYsefB.jpg","original_language":"en","original_title":"The Lion King","genre_ids":[10751,16,18],"backdrop_path":"\/klI0K4oQMsLhHdjA9Uw8WLugk9v.jpg","adult":false,"overview":"A young lion cub named Simba can't wait to be king. But his uncle craves the title for himself and will stop at nothing to get it.","release_date":"1994-06-23"},{"vote_count":5380,"id":101,"video":false,"vote_average":8.2,"title":"Leon: The Professional","popularity":34.658145,"poster_path":"\/gE8S02QUOhVnAmYu4tcrBlMTujz.jpg","original_language":"fr","original_title":"Léon","genre_ids":[53,80,18],"backdrop_path":"\/mGN0lH2phYfesyEVqP2xvGUaxAQ.jpg","adult":false,"overview":"Leon, the top hit man in New York, has earned a rep as an effective \"cleaner\". But when his next-door neighbors are wiped out by a loose-cannon DEA agent, he becomes the unwilling custodian of 12-year-old Mathilda. Before long, Mathilda's thoughts turn to revenge, and she considers following in Leon's footsteps.","release_date":"1994-09-14"},{"vote_count":10185,"id":13,"video":false,"vote_average":8.3,"title":"Forrest Gump","popularity":32.985076,"poster_path":"\/yE5d3BUhE8hCnkMUJOo1QDoOGNz.jpg","original_language":"en","original_title":"Forrest Gump","genre_ids":[35,18,10749],"backdrop_path":"\/ctOEhQiFIHWkiaYp7b0ibSTe5IL.jpg","adult":false,"overview":"A man with a low IQ has accomplished great things in his life and been present during significant historic events - in each case, far exceeding what anyone imagined he could do. Yet, despite all the things he has attained, his one true love eludes him. 'Forrest Gump' is the story of a man who rose above his challenges, and who proved that determination, courage, and love are more important than ability.","release_date":"1994-07-06"},{"vote_count":4974,"id":500,"video":false,"vote_average":8.1,"title":"Reservoir Dogs","popularity":31.872413,"poster_path":"\/tB2ITHg556e7aTV6cqQqVAXkdxN.jpg","original_language":"en","original_title":"Reservoir Dogs","genre_ids":[80,53],"backdrop_path":"\/gjOiE5EYH5sqcJYlSDZnVWRMgNV.jpg","adult":false,"overview":"A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.","release_date":"1992-09-02"},{"vote_count":2588,"id":408,"video":false,"vote_average":6.9,"title":"Snow White and the Seven Dwarfs","popularity":31.4678,"poster_path":"\/bOtgcOIFBCUFdY2a737Na6gWQ0X.jpg","original_language":"en","original_title":"Snow White and the Seven Dwarfs","genre_ids":[14,16,10751],"backdrop_path":"\/c66otZnSdri67kR7ps92kRX849o.jpg","adult":false,"overview":"A beautiful girl, Snow White, takes refuge in the forest in the house of seven dwarfs to hide from her stepmother, the wicked Queen. The Queen is jealous because she wants to be known as \"the fairest in the land,\" and Snow White's beauty surpasses her own.","release_date":"1937-12-20"},{"vote_count":9853,"id":278,"video":false,"vote_average":8.5,"title":"The Shawshank Redemption","popularity":30.801079,"poster_path":"\/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg","original_language":"en ...

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/review/%7Breview_id%7D?api_key=e7a9762dabfdc186e180a0791bb06e7c", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"status_code":34,"status_message":"The resource you requested could not be found."}
